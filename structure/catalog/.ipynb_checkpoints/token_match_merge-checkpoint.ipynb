# %%
import json
from collections import defaultdict

# %%
# Load the exported title tokens
with open('data/title_tokens_clean.json', 'r') as file:
    title_tokens_data = json.load(file)

# Load the similarity results
with open('data/similarity_results.json', 'r') as file:
    similarity_results = json.load(file)

# %%
# Create a structured dictionary where each section name contains tokens and their matches
similarity_dict = defaultdict(lambda: defaultdict(list))
for result in similarity_results:
    token = result['title_token']
    section = result['section_name']  # Assume section_name is part of the results
    if result['similarity'] > 0.1:  # Filter to only include positive similarity scores
        similarity_entry = {
            'section_token': result['section_token'],
            'similarity': result['similarity'],
            'object_id': result['object_id'],
            'title_text': result['title_text'],
            'section_id': result['section_id']
        }
        similarity_dict[section][token].append(similarity_entry)

# %%
# Example of how this structured dictionary is used
for section, tokens in list(similarity_dict.items())[:1]:  # Limit to the first section for example
    print(f"Section: {section}")
    for token, entries in tokens.items():
        print(f"  Token: {token}, Matches Count: {len(entries)}")
        for entry in entries[:3]:  # Show only the first 3 matches for each token
            print(f"    Matches with: {entry['section_token']}, Similarity: {entry['similarity']:.4f}")
# Out:
# Section: Textiles Costume and Jewelry
#   Token: wallpap, Matches Count: 343
#     Matches with: fan, Similarity: 0.2568
#     Matches with: uniform, Similarity: 0.1045
#     Matches with: pictur, Similarity: 0.1005
#   Token: bit, Matches Count: 912
#     Matches with: pocket, Similarity: 0.1487
#     Matches with: walk, Similarity: 0.1654
#     Matches with: ear, Similarity: 0.1046
#   Token: dirk, Matches Count: 38
#     Matches with: bouquet, Similarity: 0.2088
#     Matches with: bootjack, Similarity: 0.1190
#     Matches with: collar, Similarity: 0.1194
#   Token: candl, Matches Count: 2176
#     Matches with: eyeglass, Similarity: 0.1279
#     Matches with: muff, Similarity: 0.1171
#     Matches with: ear, Similarity: 0.1663
#   Token: holder, Matches Count: 3040
#     Matches with: suspend, Similarity: 0.2137
#     Matches with: carpet, Similarity: 0.1646
#     Matches with: pocket, Similarity: 0.1824
#   Token: doorway, Matches Count: 1442
#     Matches with: needlework, Similarity: 0.1882
#     Matches with: render, Similarity: 0.1140
#     Matches with: coverlet, Similarity: 0.1504
#   Token: door, Matches Count: 1562
#     Matches with: mitten, Similarity: 0.1253
#     Matches with: bouquet, Similarity: 0.2934
#     Matches with: fan, Similarity: 0.1706
#   Token: restor, Matches Count: 451
#     Matches with: glove, Similarity: 0.1047
#     Matches with: carpet, Similarity: 0.2876
#     Matches with: pocket, Similarity: 0.1679
#   Token: draw, Matches Count: 1139
#     Matches with: sampler, Similarity: 0.1129
#     Matches with: walk, Similarity: 0.1827
#     Matches with: case, Similarity: 0.1392
#   Token: grandfath, Matches Count: 600
#     Matches with: render, Similarity: 0.1526
#     Matches with: walk, Similarity: 0.1089
#     Matches with: case, Similarity: 0.1457
#   Token: clock, Matches Count: 3910
#     Matches with: suspend, Similarity: 0.1164
#     Matches with: walk, Similarity: 0.1392
#     Matches with: comb, Similarity: 0.1890
#   Token: tripod, Matches Count: 90
#     Matches with: suspend, Similarity: 0.1684
#     Matches with: mitten, Similarity: 0.2551
#     Matches with: fan, Similarity: 0.1220
#   Token: tabl, Matches Count: 6224
#     Matches with: bouquet, Similarity: 0.1570
#     Matches with: fob, Similarity: 0.1656
#     Matches with: overs, Similarity: 0.2222
#   Token: ring, Matches Count: 476
#     Matches with: bouquet, Similarity: 0.1094
#     Matches with: carpet, Similarity: 0.1102
#     Matches with: render, Similarity: 0.1604
#   Token: bottl, Matches Count: 2669
#     Matches with: glove, Similarity: 0.1638
#     Matches with: bouquet, Similarity: 0.1281
#     Matches with: fob, Similarity: 0.1003
#   Token: indian, Matches Count: 3690
#     Matches with: carpet, Similarity: 0.2266
#     Matches with: pocket, Similarity: 0.1361
#     Matches with: render, Similarity: 0.1384
#   Token: ladl, Matches Count: 595
#     Matches with: walk, Similarity: 0.2863
#     Matches with: muff, Similarity: 0.1077
#     Matches with: spectacl, Similarity: 0.1045
#   Token: sugar, Matches Count: 4152
#     Matches with: carpet, Similarity: 0.1723
#     Matches with: pocket, Similarity: 0.1351
#     Matches with: comb, Similarity: 0.1849
#   Token: bowl, Matches Count: 5544
#     Matches with: suspend, Similarity: 0.1108
#     Matches with: carpet, Similarity: 0.1059
#     Matches with: bootjack, Similarity: 0.1018
#   Token: cover, Matches Count: 2356
#     Matches with: carpet, Similarity: 0.1161
#     Matches with: bootjack, Similarity: 0.1479
#     Matches with: necklac, Similarity: 0.1643
#   Token: glass, Matches Count: 4047
#     Matches with: glove, Similarity: 0.1185
#     Matches with: sampler, Similarity: 0.1022
#     Matches with: render, Similarity: 0.1066
#   Token: lamp, Matches Count: 3123
#     Matches with: comb, Similarity: 0.1621
#     Matches with: collar, Similarity: 0.2162
#     Matches with: satchel, Similarity: 0.2954
#   Token: chamber, Matches Count: 51
#     Matches with: needlework, Similarity: 0.1006
#     Matches with: sampler, Similarity: 0.1899
#     Matches with: comb, Similarity: 0.1249
#   Token: spark, Matches Count: 168
#     Matches with: mitten, Similarity: 0.1392
#     Matches with: overs, Similarity: 0.1312
#     Matches with: comb, Similarity: 0.1715
#   Token: pewter, Matches Count: 5187
#     Matches with: fob, Similarity: 0.1675
#     Matches with: fan, Similarity: 0.1686
#     Matches with: case, Similarity: 0.1958
#   Token: coffe, Matches Count: 1210
#     Matches with: pocket, Similarity: 0.1474
#     Matches with: walk, Similarity: 0.1352
#     Matches with: parasol, Similarity: 0.1183
#   Token: pot, Matches Count: 1562
#     Matches with: suspend, Similarity: 0.1383
#     Matches with: carpet, Similarity: 0.1688
#     Matches with: render, Similarity: 0.2088
#   Token: mug, Matches Count: 2268
#     Matches with: needlework, Similarity: 0.1170
#     Matches with: carpet, Similarity: 0.1578
#     Matches with: collar, Similarity: 0.1008
#   Token: porring, Matches Count: 671
#     Matches with: case, Similarity: 0.1041
#     Matches with: tray, Similarity: 0.2303
#     Matches with: jacquard, Similarity: 0.1031
#   Token: tankard, Matches Count: 728
#     Matches with: mitten, Similarity: 0.1253
#     Matches with: walk, Similarity: 0.1818
#     Matches with: parasol, Similarity: 0.1009
#   Token: quilt, Matches Count: 9196
#     Matches with: glove, Similarity: 0.1143
#     Matches with: bouquet, Similarity: 0.1002
#     Matches with: pocket, Similarity: 0.1735
#   Token: appliqu, Matches Count: 1274
#     Matches with: sampler, Similarity: 0.1238
#     Matches with: comb, Similarity: 0.1748
#     Matches with: bootjack, Similarity: 0.2044
#   Token: coverlet, Matches Count: 4044
#     Matches with: coverlet, Similarity: 1.0000
#     Matches with: tray, Similarity: 0.1830
#     Matches with: holder, Similarity: 0.2125
#   Token: embroideri, Matches Count: 1587
#     Matches with: fob, Similarity: 0.1929
#     Matches with: needlework, Similarity: 0.1013
#     Matches with: carpet, Similarity: 0.2159
#   Token: decor, Matches Count: 3564
#     Matches with: needlework, Similarity: 0.1066
#     Matches with: carpet, Similarity: 0.2395
#     Matches with: pocket, Similarity: 0.1210
#   Token: pitcher, Matches Count: 3312
#     Matches with: collar, Similarity: 0.1182
#     Matches with: spectacl, Similarity: 0.1885
#     Matches with: satchel, Similarity: 0.1883
#   Token: silver, Matches Count: 8879
#     Matches with: sampler, Similarity: 0.1037
#     Matches with: case, Similarity: 0.1938
#     Matches with: spectacl, Similarity: 0.1584
#   Token: knife, Matches Count: 840
#     Matches with: suspend, Similarity: 0.1324
#     Matches with: sampler, Similarity: 0.1442
#     Matches with: overs, Similarity: 0.1451
#   Token: fork, Matches Count: 270
#     Matches with: needlework, Similarity: 0.1048
#     Matches with: children, Similarity: 0.1511
#     Matches with: cufflink, Similarity: 0.1522
#   Token: wall, Matches Count: 3432
#     Matches with: carpet, Similarity: 0.1370
#     Matches with: cane, Similarity: 0.2423
#     Matches with: eyeglass, Similarity: 0.1775
#   Token: cherri, Matches Count: 150
#     Matches with: eyeglass, Similarity: 0.1704
#     Matches with: overs, Similarity: 0.1156
#     Matches with: comb, Similarity: 0.1909
#   Token: satchel, Matches Count: 38
#     Matches with: overs, Similarity: 0.1139
#     Matches with: comb, Similarity: 0.1251
#     Matches with: collar, Similarity: 0.1673
#   Token: iron, Matches Count: 7224
#     Matches with: carpet, Similarity: 0.1574
#     Matches with: fan, Similarity: 0.2032
#     Matches with: case, Similarity: 0.1520
#   Token: wood, Matches Count: 639
#     Matches with: mitten, Similarity: 0.1272
#     Matches with: fob, Similarity: 0.1435
#     Matches with: case, Similarity: 0.1531
#   Token: carv, Matches Count: 2226
#     Matches with: pocket, Similarity: 0.1672
#     Matches with: eyeglass, Similarity: 0.1140
#     Matches with: skate, Similarity: 0.1924
#   Token: copper, Matches Count: 555
#     Matches with: mitten, Similarity: 0.1657
#     Matches with: bouquet, Similarity: 0.2356
#     Matches with: comb, Similarity: 0.1694
#   Token: kettl, Matches Count: 671
#     Matches with: overs, Similarity: 0.1343
#     Matches with: comb, Similarity: 0.1525
#     Matches with: muff, Similarity: 0.1022
#   Token: desk, Matches Count: 1716
#     Matches with: coverlet, Similarity: 0.1532
#     Matches with: satchel, Similarity: 0.1689
#     Matches with: necklac, Similarity: 0.2065
#   Token: american, Matches Count: 210
#     Matches with: fob, Similarity: 0.1701
#     Matches with: skate, Similarity: 0.2329
#     Matches with: muff, Similarity: 0.1342
#   Token: teapot, Matches Count: 3519
#     Matches with: pocket, Similarity: 0.2614
#     Matches with: card, Similarity: 0.1100
#     Matches with: necklac, Similarity: 0.1261
#   Token: dress, Matches Count: 11193
#     Matches with: needlework, Similarity: 0.2669
#     Matches with: sampler, Similarity: 0.1650
#     Matches with: fan, Similarity: 0.1325
#   Token: uniform, Matches Count: 140
#     Matches with: fob, Similarity: 0.1041
#     Matches with: pocket, Similarity: 0.1849
#     Matches with: render, Similarity: 0.1694
#   Token: german, Matches Count: 9612
#     Matches with: glove, Similarity: 0.1040
#     Matches with: case, Similarity: 0.1397
#     Matches with: skate, Similarity: 0.1526
#   Token: earthenwar, Matches Count: 306
#     Matches with: glove, Similarity: 0.1794
#     Matches with: render, Similarity: 0.3650
#     Matches with: fan, Similarity: 0.1129
#   Token: bird, Matches Count: 752
#     Matches with: suspend, Similarity: 0.2024
#     Matches with: mitten, Similarity: 0.3267
#     Matches with: carpet, Similarity: 0.1249
#   Token: churn, Matches Count: 517
#     Matches with: suspend, Similarity: 0.1411
#     Matches with: mitten, Similarity: 0.1849
#     Matches with: pocket, Similarity: 0.1291
#   Token: cup, Matches Count: 2112
#     Matches with: glove, Similarity: 0.1629
#     Matches with: sampler, Similarity: 0.2285
#     Matches with: overs, Similarity: 0.1092
#   Token: pennsylvania, Matches Count: 1120
#     Matches with: needlework, Similarity: 0.1957
#     Matches with: sampler, Similarity: 0.1003
#     Matches with: fan, Similarity: 0.1177
#   Token: ornament, Matches Count: 1001
#     Matches with: glove, Similarity: 0.2523
#     Matches with: eyeglass, Similarity: 0.1272
#     Matches with: overs, Similarity: 0.2173
#   Token: hors, Matches Count: 2295
#     Matches with: needlework, Similarity: 0.2099
#     Matches with: sampler, Similarity: 0.1140
#     Matches with: eyeglass, Similarity: 0.1111
#   Token: salt, Matches Count: 858
#     Matches with: glove, Similarity: 0.1151
#     Matches with: cane, Similarity: 0.1271
#     Matches with: walk, Similarity: 0.1595
#   Token: print, Matches Count: 2010
#     Matches with: fan, Similarity: 0.1158
#     Matches with: necklac, Similarity: 0.1366
#     Matches with: children, Similarity: 0.1133
#   Token: mold, Matches Count: 1650
#     Matches with: collar, Similarity: 0.1904
#     Matches with: parasol, Similarity: 0.1202
#     Matches with: cotton, Similarity: 0.2242
#   Token: shoe, Matches Count: 2057
#     Matches with: sampler, Similarity: 0.1879
#     Matches with: walk, Similarity: 0.1265
#     Matches with: necklac, Similarity: 0.1693
#   Token: chest, Matches Count: 3756
#     Matches with: mitten, Similarity: 0.2530
#     Matches with: glove, Similarity: 0.1269
#     Matches with: fob, Similarity: 0.1324
#   Token: chair, Matches Count: 6589
#     Matches with: render, Similarity: 0.1884
#     Matches with: overs, Similarity: 0.1010
#     Matches with: card, Similarity: 0.1307
#   Token: pastri, Matches Count: 39
#     Matches with: suspend, Similarity: 0.1175
#     Matches with: mitten, Similarity: 0.1439
#     Matches with: bootjack, Similarity: 0.1125
#   Token: shaker, Matches Count: 3270
#     Matches with: suspend, Similarity: 0.1690
#     Matches with: mitten, Similarity: 0.1700
#     Matches with: render, Similarity: 0.1830
#   Token: stove, Matches Count: 1394
#     Matches with: mitten, Similarity: 0.1139
#     Matches with: glove, Similarity: 0.1759
#     Matches with: render, Similarity: 0.1725
#   Token: dipper, Matches Count: 99
#     Matches with: eyeglass, Similarity: 0.2778
#     Matches with: ear, Similarity: 0.1299
#     Matches with: tray, Similarity: 0.1278
#   Token: coat, Matches Count: 1577
#     Matches with: fob, Similarity: 0.1663
#     Matches with: collar, Similarity: 0.1856
#     Matches with: ear, Similarity: 0.1486
#   Token: suit, Matches Count: 858
#     Matches with: needlework, Similarity: 0.1003
#     Matches with: walk, Similarity: 0.1350
#     Matches with: coverlet, Similarity: 0.1112
#   Token: carpet, Matches Count: 592
#     Matches with: carpet, Similarity: 1.0000
#     Matches with: cane, Similarity: 0.2117
#     Matches with: eyeglass, Similarity: 0.1082
#   Token: box, Matches Count: 5635
#     Matches with: carpet, Similarity: 0.1155
#     Matches with: pocket, Similarity: 0.1201
#     Matches with: cane, Similarity: 0.1184
#   Token: cooki, Matches Count: 130
#     Matches with: glove, Similarity: 0.1061
#     Matches with: bouquet, Similarity: 0.1275
#     Matches with: muff, Similarity: 0.1113
#   Token: cutter, Matches Count: 308
#     Matches with: bouquet, Similarity: 0.2869
#     Matches with: walk, Similarity: 0.1391
#     Matches with: fan, Similarity: 0.1644
#   Token: bishop, Matches Count: 918
#     Matches with: carpet, Similarity: 0.1230
#     Matches with: fan, Similarity: 0.1874
#     Matches with: satchel, Similarity: 0.2101
#   Token: hill, Matches Count: 612
#     Matches with: mitten, Similarity: 0.1108
#     Matches with: fob, Similarity: 0.1334
#     Matches with: overs, Similarity: 0.1296
#   Token: bell, Matches Count: 1428
#     Matches with: suspend, Similarity: 0.1496
#     Matches with: fob, Similarity: 0.1679
#     Matches with: carpet, Similarity: 0.1508
#   Token: cigar, Matches Count: 3318
#     Matches with: eyeglass, Similarity: 0.1379
#     Matches with: ornament, Similarity: 0.1248
#     Matches with: parasol, Similarity: 0.1143
#   Token: store, Matches Count: 3765
#     Matches with: case, Similarity: 0.1132
#     Matches with: bootjack, Similarity: 0.1311
#     Matches with: collar, Similarity: 0.1629
#   Token: sampler, Matches Count: 954
#     Matches with: glove, Similarity: 0.3078
#     Matches with: sampler, Similarity: 1.0000
#     Matches with: eyeglass, Similarity: 0.1279
#   Token: detail, Matches Count: 1296
#     Matches with: pocket, Similarity: 0.2006
#     Matches with: eyeglass, Similarity: 0.1005
#     Matches with: card, Similarity: 0.1213
#   Token: pictur, Matches Count: 600
#     Matches with: suspend, Similarity: 0.1585
#     Matches with: needlework, Similarity: 0.1983
#     Matches with: carpet, Similarity: 0.1151
#   Token: eagl, Matches Count: 2120
#     Matches with: carpet, Similarity: 0.2046
#     Matches with: overs, Similarity: 0.1052
#     Matches with: fan, Similarity: 0.1365
#   Token: panel, Matches Count: 810
#     Matches with: comb, Similarity: 0.1528
#     Matches with: bootjack, Similarity: 0.1703
#     Matches with: collar, Similarity: 0.1142
#   Token: rug, Matches Count: 830
#     Matches with: mitten, Similarity: 0.4198
#     Matches with: bouquet, Similarity: 0.1201
#     Matches with: case, Similarity: 0.1077
#   Token: fan, Matches Count: 304
#     Matches with: fob, Similarity: 0.1456
#     Matches with: walk, Similarity: 0.1060
#     Matches with: fan, Similarity: 1.0000
#   Token: collar, Matches Count: 572
#     Matches with: suspend, Similarity: 0.2137
#     Matches with: carpet, Similarity: 0.1238
#     Matches with: comb, Similarity: 0.1735
#   Token: garden, Matches Count: 1060
#     Matches with: bouquet, Similarity: 0.1374
#     Matches with: walk, Similarity: 0.1882
#     Matches with: spectacl, Similarity: 0.1058
#   Token: bench, Matches Count: 550
#     Matches with: mitten, Similarity: 0.1255
#     Matches with: fob, Similarity: 0.2863
#     Matches with: skate, Similarity: 0.1217
#   Token: bed, Matches Count: 1358
#     Matches with: pocket, Similarity: 0.1172
#     Matches with: sampler, Similarity: 0.1034
#     Matches with: comb, Similarity: 0.1241
#   Token: tub, Matches Count: 195
#     Matches with: suspend, Similarity: 0.1694
#     Matches with: mitten, Similarity: 0.1203
#     Matches with: bouquet, Similarity: 0.1214
#   Token: jack, Matches Count: 308
#     Matches with: suspend, Similarity: 0.1527
#     Matches with: bouquet, Similarity: 0.2307
#     Matches with: coverlet, Similarity: 0.1582
#   Token: figur, Matches Count: 2584
#     Matches with: glove, Similarity: 0.2311
#     Matches with: bouquet, Similarity: 0.1598
#     Matches with: carpet, Similarity: 0.2109
#   Token: work, Matches Count: 391
#     Matches with: render, Similarity: 0.1197
#     Matches with: cane, Similarity: 0.2304
#     Matches with: fan, Similarity: 0.1048
#   Token: machin, Matches Count: 126
#     Matches with: suspend, Similarity: 0.1235
#     Matches with: fob, Similarity: 0.1604
#     Matches with: carpet, Similarity: 0.1424
#   Token: hardwar, Matches Count: 72
#     Matches with: glove, Similarity: 0.1421
#     Matches with: sampler, Similarity: 0.2273
#     Matches with: overs, Similarity: 0.1735
#   Token: costum, Matches Count: 512
#     Matches with: mitten, Similarity: 0.1005
#     Matches with: overs, Similarity: 0.1103
#     Matches with: fan, Similarity: 0.1108
#   Token: ear, Matches Count: 777
#     Matches with: glove, Similarity: 0.1592
#     Matches with: needlework, Similarity: 0.1117
#     Matches with: eyeglass, Similarity: 0.1241
#   Token: stool, Matches Count: 299
#     Matches with: suspend, Similarity: 0.1002
#     Matches with: render, Similarity: 0.1596
#     Matches with: eyeglass, Similarity: 0.1194
#   Token: grinder, Matches Count: 442
#     Matches with: suspend, Similarity: 0.1758
#     Matches with: fob, Similarity: 0.1122
#     Matches with: needlework, Similarity: 0.1063
#   Token: toy, Matches Count: 4180
#     Matches with: glove, Similarity: 0.1569
#     Matches with: sampler, Similarity: 0.1186
#     Matches with: render, Similarity: 0.1759
#   Token: set, Matches Count: 209
#     Matches with: glove, Similarity: 0.1142
#     Matches with: needlework, Similarity: 0.1040
#     Matches with: ear, Similarity: 0.1906
#   Token: compot, Matches Count: 385
#     Matches with: pocket, Similarity: 0.1299
#     Matches with: cane, Similarity: 0.1950
#     Matches with: eyeglass, Similarity: 0.1142
#   Token: post, Matches Count: 1424
#     Matches with: suspend, Similarity: 0.1367
#     Matches with: sampler, Similarity: 0.1291
#     Matches with: fan, Similarity: 0.1072
#   Token: tray, Matches Count: 1206
#     Matches with: bouquet, Similarity: 0.2320
#     Matches with: fan, Similarity: 0.1748
#     Matches with: spectacl, Similarity: 0.1886
#   Token: spur, Matches Count: 1316
#     Matches with: fob, Similarity: 0.1872
#     Matches with: fan, Similarity: 0.2373
#     Matches with: collar, Similarity: 0.1102
#   Token: form, Matches Count: 76
#     Matches with: suspend, Similarity: 0.1222
#     Matches with: mitten, Similarity: 0.1315
#     Matches with: pocket, Similarity: 0.2295
#   Token: bootjack, Matches Count: 920
#     Matches with: fob, Similarity: 0.1272
#     Matches with: sampler, Similarity: 0.1320
#     Matches with: fan, Similarity: 0.1088
#   Token: metal, Matches Count: 392
#     Matches with: bouquet, Similarity: 0.1296
#     Matches with: pocket, Similarity: 0.1551
#     Matches with: spectacl, Similarity: 0.1614
#   Token: fireplac, Matches Count: 378
#     Matches with: glove, Similarity: 0.1557
#     Matches with: comb, Similarity: 0.2032
#     Matches with: collar, Similarity: 0.2243
#   Token: shovel, Matches Count: 459
#     Matches with: suspend, Similarity: 0.1587
#     Matches with: fob, Similarity: 0.1644
#     Matches with: needlework, Similarity: 0.1323
#   Token: hay, Matches Count: 126
#     Matches with: bouquet, Similarity: 0.1169
#     Matches with: skate, Similarity: 0.1143
#     Matches with: shoe, Similarity: 0.1571
#   Token: railway, Matches Count: 11
#     Matches with: sampler, Similarity: 0.1027
#     Matches with: muff, Similarity: 0.2127
#     Matches with: ear, Similarity: 0.1174
#   Token: pail, Matches Count: 80
#     Matches with: sampler, Similarity: 0.1918
#     Matches with: collar, Similarity: 0.1630
#     Matches with: jacquard, Similarity: 0.1053
#   Token: pick, Matches Count: 14
#     Matches with: render, Similarity: 0.1611
#     Matches with: skate, Similarity: 0.1301
#     Matches with: ornament, Similarity: 0.1691
#   Token: plane, Matches Count: 330
#     Matches with: mitten, Similarity: 0.1324
#     Matches with: sampler, Similarity: 0.1413
#     Matches with: coverlet, Similarity: 0.2358
#   Token: cloth, Matches Count: 448
#     Matches with: mitten, Similarity: 0.1602
#     Matches with: glove, Similarity: 0.2511
#     Matches with: carpet, Similarity: 0.1092
#   Token: yoke, Matches Count: 256
#     Matches with: suspend, Similarity: 0.1160
#     Matches with: glove, Similarity: 0.1009
#     Matches with: bouquet, Similarity: 0.2108
#   Token: wrench, Matches Count: 24
#     Matches with: render, Similarity: 0.2087
#     Matches with: card, Similarity: 0.1700
#     Matches with: parasol, Similarity: 0.1466
#   Token: decoy, Matches Count: 297
#     Matches with: fan, Similarity: 0.3139
#     Matches with: tray, Similarity: 0.1542
#     Matches with: cuff, Similarity: 0.1106
#   Token: fish, Matches Count: 260
#     Matches with: needlework, Similarity: 0.1312
#     Matches with: render, Similarity: 0.1973
#     Matches with: eyeglass, Similarity: 0.1268
#   Token: spear, Matches Count: 36
#     Matches with: case, Similarity: 0.2024
#     Matches with: comb, Similarity: 0.1428
#     Matches with: cotton, Similarity: 0.1329
#   Token: cradl, Matches Count: 663
#     Matches with: mitten, Similarity: 0.1108
#     Matches with: carpet, Similarity: 0.1015
#     Matches with: cane, Similarity: 0.1005
#   Token: sofa, Matches Count: 896
#     Matches with: mitten, Similarity: 0.1960
#     Matches with: needlework, Similarity: 0.1580
#     Matches with: sampler, Similarity: 0.1009
#   Token: cotton, Matches Count: 1053
#     Matches with: suspend, Similarity: 0.1263
#     Matches with: cotton, Similarity: 1.0000
#     Matches with: children, Similarity: 0.1475
#   Token: marker, Matches Count: 169
#     Matches with: suspend, Similarity: 0.1832
#     Matches with: mitten, Similarity: 0.2671
#     Matches with: bootjack, Similarity: 0.1419
#   Token: paint, Matches Count: 3077
#     Matches with: bouquet, Similarity: 0.1364
#     Matches with: comb, Similarity: 0.2137
#     Matches with: collar, Similarity: 0.1191
#   Token: religi, Matches Count: 56
#     Matches with: suspend, Similarity: 0.1561
#     Matches with: mitten, Similarity: 0.1298
#     Matches with: fan, Similarity: 0.1225
#   Token: design, Matches Count: 4438
#     Matches with: comb, Similarity: 0.2872
#     Matches with: necklac, Similarity: 0.1145
#     Matches with: holder, Similarity: 0.1263
#   Token: bandbox, Matches Count: 2322
#     Matches with: mitten, Similarity: 0.1473
#     Matches with: cane, Similarity: 0.2019
#     Matches with: coverlet, Similarity: 0.1006
#   Token: cemeteri, Matches Count: 8
#     Matches with: coverlet, Similarity: 0.1456
#     Matches with: holder, Similarity: 0.1987
#     Matches with: waist, Similarity: 0.1327
#   Token: music, Matches Count: 120
#     Matches with: collar, Similarity: 0.1428
#     Matches with: cotton, Similarity: 0.1345
#     Matches with: hair, Similarity: 0.1232
#   Token: skate, Matches Count: 234
#     Matches with: glove, Similarity: 0.1731
#     Matches with: fob, Similarity: 0.1912
#     Matches with: render, Similarity: 0.1519
#   Token: corn, Matches Count: 210
#     Matches with: fob, Similarity: 0.1622
#     Matches with: needlework, Similarity: 0.2826
#     Matches with: necklac, Similarity: 0.1328
#   Token: hitch, Matches Count: 806
#     Matches with: suspend, Similarity: 0.1031
#     Matches with: pocket, Similarity: 0.1779
#     Matches with: render, Similarity: 0.1097
#   Token: sheath, Matches Count: 170
#     Matches with: needlework, Similarity: 0.1257
#     Matches with: sampler, Similarity: 0.2455
#     Matches with: eyeglass, Similarity: 0.1788
#   Token: sausag, Matches Count: 192
#     Matches with: glove, Similarity: 0.1163
#     Matches with: bouquet, Similarity: 0.1245
#     Matches with: fob, Similarity: 0.1020
#   Token: stuffer, Matches Count: 125
#     Matches with: glove, Similarity: 0.2382
#     Matches with: pocket, Similarity: 0.1618
#     Matches with: sampler, Similarity: 0.1474
#   Token: funnel, Matches Count: 68
#     Matches with: sampler, Similarity: 0.1728
#     Matches with: cane, Similarity: 0.1169
#     Matches with: fan, Similarity: 0.1439
#   Token: roll, Matches Count: 132
#     Matches with: bouquet, Similarity: 0.1021
#     Matches with: fob, Similarity: 0.2598
#     Matches with: eyeglass, Similarity: 0.1404
#   Token: pin, Matches Count: 1062
#     Matches with: pocket, Similarity: 0.1439
#     Matches with: overs, Similarity: 0.1549
#     Matches with: tray, Similarity: 0.1408
#   Token: ship, Matches Count: 473
#     Matches with: walk, Similarity: 0.1133
#     Matches with: parasol, Similarity: 0.1211
#     Matches with: cotton, Similarity: 0.2173
#   Token: saw, Matches Count: 171
#     Matches with: glove, Similarity: 0.1296
#     Matches with: bouquet, Similarity: 0.1442
#     Matches with: cane, Similarity: 0.1514
#   Token: case, Matches Count: 1026
#     Matches with: mitten, Similarity: 0.1011
#     Matches with: glove, Similarity: 0.1590
#     Matches with: sampler, Similarity: 0.1204
#   Token: shoemak, Matches Count: 110
#     Matches with: glove, Similarity: 0.2289
#     Matches with: carpet, Similarity: 0.1059
#     Matches with: sampler, Similarity: 0.2235
#   Token: furnitur, Matches Count: 126
#     Matches with: fob, Similarity: 0.1296
#     Matches with: sampler, Similarity: 0.1446
#     Matches with: bootjack, Similarity: 0.1249
#   Token: stern, Matches Count: 558
#     Matches with: sampler, Similarity: 0.1344
#     Matches with: eyeglass, Similarity: 0.1097
#     Matches with: walk, Similarity: 0.1754
#   Token: piec, Matches Count: 1248
#     Matches with: satchel, Similarity: 0.1509
#     Matches with: holder, Similarity: 0.1071
#     Matches with: bracelet, Similarity: 0.2122
#   Token: sign, Matches Count: 1230
#     Matches with: skate, Similarity: 0.1106
#     Matches with: spectacl, Similarity: 0.1331
#     Matches with: ear, Similarity: 0.1234
#   Token: shop, Matches Count: 264
#     Matches with: pocket, Similarity: 0.1277
#     Matches with: fan, Similarity: 0.1485
#     Matches with: textil, Similarity: 0.1005
#   Token: skewer, Matches Count: 105
#     Matches with: pocket, Similarity: 0.1144
#     Matches with: render, Similarity: 0.1033
#     Matches with: walk, Similarity: 0.1236
#   Token: comb, Matches Count: 748
#     Matches with: overs, Similarity: 0.2926
#     Matches with: comb, Similarity: 1.0000
#     Matches with: bootjack, Similarity: 0.1470
#   Token: devic, Matches Count: 22
#     Matches with: render, Similarity: 0.1185
#     Matches with: eyeglass, Similarity: 0.1492
#     Matches with: case, Similarity: 0.1204
#   Token: washer, Matches Count: 14
#     Matches with: render, Similarity: 0.1135
#     Matches with: cane, Similarity: 0.1533
#     Matches with: spectacl, Similarity: 0.1792
#   Token: clamp, Matches Count: 75
#     Matches with: suspend, Similarity: 0.1972
#     Matches with: bouquet, Similarity: 0.1151
#     Matches with: pocket, Similarity: 0.1363
#   Token: leather, Matches Count: 351
#     Matches with: eyeglass, Similarity: 0.1211
#     Matches with: satchel, Similarity: 0.1396
#     Matches with: ornament, Similarity: 0.1108
#   Token: bucket, Matches Count: 288
#     Matches with: overs, Similarity: 0.1159
#     Matches with: coverlet, Similarity: 0.1878
#     Matches with: cotton, Similarity: 0.1111
#   Token: hook, Matches Count: 858
#     Matches with: glove, Similarity: 0.1534
#     Matches with: eyeglass, Similarity: 0.1199
#     Matches with: walk, Similarity: 0.1687
#   Token: club, Matches Count: 84
#     Matches with: glove, Similarity: 0.1174
#     Matches with: fob, Similarity: 0.1045
#     Matches with: needlework, Similarity: 0.2295
#   Token: mallet, Matches Count: 21
#     Matches with: pocket, Similarity: 0.1317
#     Matches with: clog, Similarity: 0.1536
#     Matches with: stock, Similarity: 0.1665
#   Token: build, Matches Count: 91
#     Matches with: fob, Similarity: 0.1916
#     Matches with: muff, Similarity: 0.1846
#     Matches with: ear, Similarity: 0.1910
#   Token: firemark, Matches Count: 340
#     Matches with: suspend, Similarity: 0.2312
#     Matches with: glove, Similarity: 0.1640
#     Matches with: walk, Similarity: 0.1023
#   Token: belt, Matches Count: 225
#     Matches with: comb, Similarity: 0.1919
#     Matches with: muff, Similarity: 0.1834
#     Matches with: satchel, Similarity: 0.1587
#   Token: auger, Matches Count: 91
#     Matches with: mitten, Similarity: 0.1808
#     Matches with: fob, Similarity: 0.1222
#     Matches with: pocket, Similarity: 0.2563
#   Token: basket, Matches Count: 1232
#     Matches with: bouquet, Similarity: 0.1503
#     Matches with: needlework, Similarity: 0.1044
#     Matches with: pocket, Similarity: 0.1103
#   Token: brace, Matches Count: 171
#     Matches with: suspend, Similarity: 0.1712
#     Matches with: carpet, Similarity: 0.1313
#     Matches with: case, Similarity: 0.1116
#   Token: brand, Matches Count: 1064
#     Matches with: glove, Similarity: 0.2306
#     Matches with: needlework, Similarity: 0.1078
#     Matches with: carpet, Similarity: 0.1499
#   Token: masher, Matches Count: 119
#     Matches with: suspend, Similarity: 0.2338
#     Matches with: needlework, Similarity: 0.1116
#     Matches with: muff, Similarity: 0.1277
#   Token: grain, Matches Count: 255
#     Matches with: glove, Similarity: 0.1542
#     Matches with: bouquet, Similarity: 0.1179
#     Matches with: needlework, Similarity: 0.2906
#   Token: pestl, Matches Count: 364
#     Matches with: needlework, Similarity: 0.2441
#     Matches with: sampler, Similarity: 0.1837
#     Matches with: muff, Similarity: 0.1145
#   Token: scoop, Matches Count: 117
#     Matches with: walk, Similarity: 0.1692
#     Matches with: comb, Similarity: 0.1343
#     Matches with: parasol, Similarity: 0.1461
#   Token: figurehead, Matches Count: 2176
#     Matches with: needlework, Similarity: 0.1370
#     Matches with: walk, Similarity: 0.1064
#     Matches with: card, Similarity: 0.1883
#   Token: necklac, Matches Count: 209
#     Matches with: glove, Similarity: 0.2901
#     Matches with: bouquet, Similarity: 0.2000
#     Matches with: carpet, Similarity: 0.1028
#   Token: billet, Matches Count: 60
#     Matches with: suspend, Similarity: 0.1299
#     Matches with: fob, Similarity: 0.1387
#     Matches with: bootjack, Similarity: 0.1565
#   Token: room, Matches Count: 403
#     Matches with: suspend, Similarity: 0.2865
#     Matches with: pocket, Similarity: 0.1451
#     Matches with: walk, Similarity: 0.1725
#   Token: cabinet, Matches Count: 1050
#     Matches with: needlework, Similarity: 0.1357
#     Matches with: cane, Similarity: 0.1135
#     Matches with: overs, Similarity: 0.1251
#   Token: cupboard, Matches Count: 1200
#     Matches with: glove, Similarity: 0.1414
#     Matches with: walk, Similarity: 0.1019
#     Matches with: skate, Similarity: 0.1422
#   Token: secretari, Matches Count: 372
#     Matches with: mitten, Similarity: 0.1795
#     Matches with: glove, Similarity: 0.1658
#     Matches with: comb, Similarity: 0.1248
#   Token: measur, Matches Count: 180
#     Matches with: bouquet, Similarity: 0.1922
#     Matches with: render, Similarity: 0.1147
#     Matches with: skate, Similarity: 0.1515
#   Token: rattl, Matches Count: 187
#     Matches with: bootjack, Similarity: 0.1485
#     Matches with: cotton, Similarity: 0.2008
#     Matches with: umbrella, Similarity: 0.1401
#   Token: spoon, Matches Count: 1635
#     Matches with: carpet, Similarity: 0.1068
#     Matches with: comb, Similarity: 0.1329
#     Matches with: bootjack, Similarity: 0.1423
#   Token: pocket, Matches Count: 361
#     Matches with: bouquet, Similarity: 0.1869
#     Matches with: pocket, Similarity: 1.0000
#     Matches with: render, Similarity: 0.1839
#   Token: lowboy, Matches Count: 154
#     Matches with: carpet, Similarity: 0.1475
#     Matches with: sampler, Similarity: 0.1042
#     Matches with: eyeglass, Similarity: 0.1103
#   Token: mirror, Matches Count: 1296
#     Matches with: glove, Similarity: 0.1665
#     Matches with: render, Similarity: 0.1706
#     Matches with: overs, Similarity: 0.2759
#   Token: sette, Matches Count: 585
#     Matches with: bouquet, Similarity: 0.1723
#     Matches with: pocket, Similarity: 0.1115
#     Matches with: sampler, Similarity: 0.1431
#   Token: pan, Matches Count: 476
#     Matches with: case, Similarity: 0.1155
#     Matches with: ear, Similarity: 0.3130
#     Matches with: tray, Similarity: 0.1163
#   Token: tolewar, Matches Count: 1008
#     Matches with: mitten, Similarity: 0.1274
#     Matches with: glove, Similarity: 0.1161
#     Matches with: walk, Similarity: 0.2157
#   Token: trouser, Matches Count: 224
#     Matches with: sampler, Similarity: 0.1719
#     Matches with: case, Similarity: 0.1385
#     Matches with: bracelet, Similarity: 0.1367
#   Token: jacquard, Matches Count: 117
#     Matches with: pocket, Similarity: 0.1185
#     Matches with: sampler, Similarity: 0.1054
#     Matches with: cane, Similarity: 0.1103
#   Token: woven, Matches Count: 960
#     Matches with: glove, Similarity: 0.1389
#     Matches with: needlework, Similarity: 0.1622
#     Matches with: cane, Similarity: 0.1528
#   Token: board, Matches Count: 620
#     Matches with: mitten, Similarity: 0.1265
#     Matches with: needlework, Similarity: 0.1281
#     Matches with: pocket, Similarity: 0.1257
#   Token: stencil, Matches Count: 864
#     Matches with: needlework, Similarity: 0.1149
#     Matches with: render, Similarity: 0.1818
#     Matches with: cane, Similarity: 0.2163
#   Token: skimmer, Matches Count: 54
#     Matches with: fob, Similarity: 0.1132
#     Matches with: skate, Similarity: 0.1451
#     Matches with: ear, Similarity: 0.1319
#   Token: art, Matches Count: 2489
#     Matches with: mitten, Similarity: 0.2409
#     Matches with: glove, Similarity: 0.1441
#     Matches with: bouquet, Similarity: 0.1403
#   Token: spanish, Matches Count: 4032
#     Matches with: suspend, Similarity: 0.1279
#     Matches with: comb, Similarity: 0.2689
#     Matches with: bootjack, Similarity: 0.1136
#   Token: california, Matches Count: 540
#     Matches with: needlework, Similarity: 0.1038
#     Matches with: cane, Similarity: 0.1015
#     Matches with: walk, Similarity: 0.1643
#   Token: purs, Matches Count: 736
#     Matches with: mitten, Similarity: 0.1093
#     Matches with: cane, Similarity: 0.1253
#     Matches with: case, Similarity: 0.2206
#   Token: quaker, Matches Count: 364
#     Matches with: bouquet, Similarity: 0.2205
#     Matches with: ear, Similarity: 0.1376
#     Matches with: necklac, Similarity: 0.1098
#   Token: textil, Matches Count: 1744
#     Matches with: carpet, Similarity: 0.1054
#     Matches with: render, Similarity: 0.1597
#     Matches with: cane, Similarity: 0.1630
#   Token: linen, Matches Count: 688
#     Matches with: eyeglass, Similarity: 0.1354
#     Matches with: bootjack, Similarity: 0.2174
#     Matches with: skate, Similarity: 0.1486
#   Token: tool, Matches Count: 195
#     Matches with: render, Similarity: 0.1367
#     Matches with: collar, Similarity: 0.1208
#     Matches with: spectacl, Similarity: 0.2143
#   Token: game, Matches Count: 104
#     Matches with: glove, Similarity: 0.1103
#     Matches with: case, Similarity: 0.1081
#     Matches with: collar, Similarity: 0.1413
#   Token: rig, Matches Count: 51
#     Matches with: render, Similarity: 0.1195
#     Matches with: muff, Similarity: 0.1979
#     Matches with: parasol, Similarity: 0.1060
#   Token: saddl, Matches Count: 1104
#     Matches with: glove, Similarity: 0.1712
#     Matches with: pocket, Similarity: 0.1215
#     Matches with: sampler, Similarity: 0.1477
#   Token: sideboard, Matches Count: 266
#     Matches with: fan, Similarity: 0.1732
#     Matches with: bootjack, Similarity: 0.1352
#     Matches with: card, Similarity: 0.1177
#   Token: interior, Matches Count: 280
#     Matches with: render, Similarity: 0.1283
#     Matches with: case, Similarity: 0.1473
#     Matches with: coverlet, Similarity: 0.1499
#   Token: hammer, Matches Count: 90
#     Matches with: pocket, Similarity: 0.2702
#     Matches with: eyeglass, Similarity: 0.1114
#     Matches with: bootjack, Similarity: 0.1014
#   Token: tong, Matches Count: 420
#     Matches with: sampler, Similarity: 0.1145
#     Matches with: comb, Similarity: 0.1280
#     Matches with: ornament, Similarity: 0.1233
#   Token: highboy, Matches Count: 630
#     Matches with: suspend, Similarity: 0.1138
#     Matches with: bouquet, Similarity: 0.2617
#     Matches with: pocket, Similarity: 0.2244
#   Token: car, Matches Count: 144
#     Matches with: bouquet, Similarity: 0.1821
#     Matches with: fan, Similarity: 0.1551
#     Matches with: collar, Similarity: 0.1065
#   Token: spatula, Matches Count: 72
#     Matches with: suspend, Similarity: 0.1636
#     Matches with: mitten, Similarity: 0.1324
#     Matches with: fob, Similarity: 0.1908
#   Token: four, Matches Count: 110
#     Matches with: fob, Similarity: 0.1240
#     Matches with: children, Similarity: 0.1818
#     Matches with: four, Similarity: 1.0000
#   Token: architectur, Matches Count: 156
#     Matches with: sampler, Similarity: 0.1711
#     Matches with: eyeglass, Similarity: 0.1349
#     Matches with: umbrella, Similarity: 0.1027
#   Token: silk, Matches Count: 800
#     Matches with: walk, Similarity: 0.1513
#     Matches with: case, Similarity: 0.1443
#     Matches with: comb, Similarity: 0.1237
#   Token: hair, Matches Count: 364
#     Matches with: case, Similarity: 0.1144
#     Matches with: bootjack, Similarity: 0.1406
#     Matches with: collar, Similarity: 0.1919
#   Token: whirligig, Matches Count: 221
#     Matches with: fob, Similarity: 0.1669
#     Matches with: comb, Similarity: 0.1390
#     Matches with: skate, Similarity: 0.2674
#   Token: map, Matches Count: 55
#     Matches with: skate, Similarity: 0.2672
#     Matches with: muff, Similarity: 0.1379
#     Matches with: card, Similarity: 0.1622
#   Token: sculptur, Matches Count: 26
#     Matches with: suspend, Similarity: 0.1072
#     Matches with: case, Similarity: 0.1301
#     Matches with: collar, Similarity: 0.1843
#   Token: embroid, Matches Count: 750
#     Matches with: bootjack, Similarity: 0.1491
#     Matches with: satchel, Similarity: 0.1647
#     Matches with: embroid, Similarity: 1.0000
#   Token: light, Matches Count: 204
#     Matches with: render, Similarity: 0.1881
#     Matches with: fan, Similarity: 0.1734
#     Matches with: coverlet, Similarity: 0.2681
#   Token: render, Matches Count: 51
#     Matches with: glove, Similarity: 0.1817
#     Matches with: pocket, Similarity: 0.1839
#     Matches with: render, Similarity: 1.0000
#   Token: chalkwar, Matches Count: 795
#     Matches with: pocket, Similarity: 0.1345
#     Matches with: case, Similarity: 0.1847
#     Matches with: card, Similarity: 0.1471
#   Token: gavel, Matches Count: 18
#     Matches with: overs, Similarity: 0.1403
#     Matches with: case, Similarity: 0.1814
#     Matches with: card, Similarity: 0.1751
#   Token: zoar, Matches Count: 798
#     Matches with: mitten, Similarity: 0.1073
#     Matches with: bouquet, Similarity: 0.1947
#     Matches with: needlework, Similarity: 0.1185
#   Token: mitt, Matches Count: 126
#     Matches with: overs, Similarity: 0.1301
#     Matches with: fan, Similarity: 0.3194
#     Matches with: case, Similarity: 0.1088
#   Token: suspend, Matches Count: 50
#     Matches with: suspend, Similarity: 1.0000
#     Matches with: mitten, Similarity: 0.1833
#     Matches with: walk, Similarity: 0.1541
#   Token: card, Matches Count: 598
#     Matches with: glove, Similarity: 0.2026
#     Matches with: pocket, Similarity: 0.1171
#     Matches with: sampler, Similarity: 0.1513
#   Token: mortar, Matches Count: 270
#     Matches with: fob, Similarity: 0.1040
#     Matches with: muff, Similarity: 0.1628
#     Matches with: cuff, Similarity: 0.2147
#   Token: bracelet, Matches Count: 320
#     Matches with: glove, Similarity: 0.1080
#     Matches with: fob, Similarity: 0.1653
#     Matches with: overs, Similarity: 0.1803
#   Token: drain, Matches Count: 30
#     Matches with: needlework, Similarity: 0.1414
#     Matches with: pocket, Similarity: 0.1822
#     Matches with: spectacl, Similarity: 0.1969
#   Token: piggin, Matches Count: 51
#     Matches with: suspend, Similarity: 0.1307
#     Matches with: pocket, Similarity: 0.1075
#     Matches with: sampler, Similarity: 0.1452
#   Token: well, Matches Count: 126
#     Matches with: bouquet, Similarity: 0.1137
#     Matches with: walk, Similarity: 0.1172
#     Matches with: fan, Similarity: 0.1055
#   Token: mitten, Matches Count: 45
#     Matches with: suspend, Similarity: 0.1833
#     Matches with: mitten, Similarity: 1.0000
#     Matches with: case, Similarity: 0.1011
#   Token: wallet, Matches Count: 68
#     Matches with: fob, Similarity: 0.1607
#     Matches with: needlework, Similarity: 0.1210
#     Matches with: sampler, Similarity: 0.1927
#   Token: stamp, Matches Count: 196
#     Matches with: suspend, Similarity: 0.1252
#     Matches with: mitten, Similarity: 0.1278
#     Matches with: pocket, Similarity: 0.1278
#   Token: flail, Matches Count: 76
#     Matches with: glove, Similarity: 0.1144
#     Matches with: bouquet, Similarity: 0.1488
#     Matches with: pocket, Similarity: 0.1340
#   Token: axe, Matches Count: 180
#     Matches with: bouquet, Similarity: 0.1077
#     Matches with: walk, Similarity: 0.1121
#     Matches with: overs, Similarity: 0.1942
#   Token: pitter, Matches Count: 27
#     Matches with: skate, Similarity: 0.1057
#     Matches with: ear, Similarity: 0.1190
#     Matches with: coverlet, Similarity: 0.2736
#   Token: mill, Matches Count: 180
#     Matches with: suspend, Similarity: 0.1713
#     Matches with: mitten, Similarity: 0.1790
#     Matches with: walk, Similarity: 0.1704
#   Token: waist, Matches Count: 117
#     Matches with: bouquet, Similarity: 0.2407
#     Matches with: cane, Similarity: 0.1200
#     Matches with: necklac, Similarity: 0.1863
#   Token: cream, Matches Count: 484
#     Matches with: eyeglass, Similarity: 0.1844
#     Matches with: overs, Similarity: 0.1876
#     Matches with: fan, Similarity: 0.1453
#   Token: scraper, Matches Count: 513
#     Matches with: needlework, Similarity: 0.1230
#     Matches with: sampler, Similarity: 0.1756
#     Matches with: case, Similarity: 0.1698
#   Token: settl, Matches Count: 45
#     Matches with: render, Similarity: 0.1309
#     Matches with: fan, Similarity: 0.1534
#     Matches with: comb, Similarity: 0.1321
#   Token: southwest, Matches Count: 68
#     Matches with: mitten, Similarity: 0.1827
#     Matches with: cane, Similarity: 0.1278
#     Matches with: skate, Similarity: 0.1802
#   Token: amana, Matches Count: 78
#     Matches with: mitten, Similarity: 0.1474
#     Matches with: bouquet, Similarity: 0.1470
#     Matches with: render, Similarity: 0.1602
#   Token: hoe, Matches Count: 119
#     Matches with: suspend, Similarity: 0.1894
#     Matches with: eyeglass, Similarity: 0.1334
#     Matches with: walk, Similarity: 0.1599
#   Token: flour, Matches Count: 80
#     Matches with: needlework, Similarity: 0.1757
#     Matches with: case, Similarity: 0.1119
#     Matches with: skate, Similarity: 0.1729
#   Token: sifter, Matches Count: 36
#     Matches with: mitten, Similarity: 0.2023
#     Matches with: spectacl, Similarity: 0.1470
#     Matches with: ornament, Similarity: 0.1004
#   Token: men, Matches Count: 75
#     Matches with: cane, Similarity: 0.1174
#     Matches with: walk, Similarity: 0.2054
#     Matches with: muff, Similarity: 0.1242
#   Token: trailboard, Matches Count: 40
#     Matches with: carpet, Similarity: 0.1936
#     Matches with: cane, Similarity: 0.1120
#     Matches with: eyeglass, Similarity: 0.1410
#   Token: anim, Matches Count: 160
#     Matches with: pocket, Similarity: 0.1376
#     Matches with: comb, Similarity: 0.1055
#     Matches with: spectacl, Similarity: 0.1327
#   Token: brooch, Matches Count: 828
#     Matches with: satchel, Similarity: 0.1995
#     Matches with: embroid, Similarity: 0.1076
#     Matches with: bracelet, Similarity: 0.1955
#   Token: buckl, Matches Count: 651
#     Matches with: carpet, Similarity: 0.2780
#     Matches with: eyeglass, Similarity: 0.2352
#     Matches with: walk, Similarity: 0.1695
#   Token: watch, Matches Count: 481
#     Matches with: cane, Similarity: 0.1922
#     Matches with: walk, Similarity: 0.1275
#     Matches with: children, Similarity: 0.1311
#   Token: fob, Matches Count: 108
#     Matches with: fob, Similarity: 1.0000
#     Matches with: fan, Similarity: 0.1456
#     Matches with: bootjack, Similarity: 0.1272
#   Token: walk, Matches Count: 247
#     Matches with: suspend, Similarity: 0.1541
#     Matches with: needlework, Similarity: 0.1833
#     Matches with: eyeglass, Similarity: 0.1132
#   Token: keg, Matches Count: 162
#     Matches with: mitten, Similarity: 0.1431
#     Matches with: sampler, Similarity: 0.1723
#     Matches with: comb, Similarity: 0.2030
#   Token: crewel, Matches Count: 903
#     Matches with: needlework, Similarity: 0.1455
#     Matches with: pocket, Similarity: 0.3664
#     Matches with: spectacl, Similarity: 0.1360
#   Token: stock, Matches Count: 228
#     Matches with: eyeglass, Similarity: 0.1314
#     Matches with: bootjack, Similarity: 0.3364
#     Matches with: collar, Similarity: 0.1606
#   Token: apron, Matches Count: 408
#     Matches with: bouquet, Similarity: 0.1490
#     Matches with: fob, Similarity: 0.2179
#     Matches with: pocket, Similarity: 0.1233
#   Token: nut, Matches Count: 64
#     Matches with: bouquet, Similarity: 0.1288
#     Matches with: fob, Similarity: 0.1608
#     Matches with: walk, Similarity: 0.1665
#   Token: barrel, Matches Count: 102
#     Matches with: suspend, Similarity: 0.1507
#     Matches with: render, Similarity: 0.1607
#     Matches with: spectacl, Similarity: 0.1882
#   Token: piano, Matches Count: 162
#     Matches with: mitten, Similarity: 0.1764
#     Matches with: carpet, Similarity: 0.1265
#     Matches with: uniform, Similarity: 0.1224
#   Token: handbag, Matches Count: 100
#     Matches with: bouquet, Similarity: 0.1647
#     Matches with: spectacl, Similarity: 0.2032
#     Matches with: satchel, Similarity: 0.2457
#   Token: parasol, Matches Count: 144
#     Matches with: render, Similarity: 0.1220
#     Matches with: spectacl, Similarity: 0.2013
#     Matches with: tray, Similarity: 0.1430
#   Token: jewelri, Matches Count: 144
#     Matches with: bouquet, Similarity: 0.1065
#     Matches with: comb, Similarity: 0.1461
#     Matches with: skate, Similarity: 0.1446
#   Token: ice, Matches Count: 294
#     Matches with: carpet, Similarity: 0.1204
#     Matches with: pocket, Similarity: 0.1856
#     Matches with: collar, Similarity: 0.1747
#   Token: pipe, Matches Count: 352
#     Matches with: bouquet, Similarity: 0.1622
#     Matches with: pocket, Similarity: 0.2218
#     Matches with: render, Similarity: 0.1429
#   Token: dough, Matches Count: 210
#     Matches with: bouquet, Similarity: 0.1136
#     Matches with: needlework, Similarity: 0.1736
#     Matches with: carpet, Similarity: 0.1092
#   Token: ceram, Matches Count: 132
#     Matches with: fob, Similarity: 0.1333
#     Matches with: needlework, Similarity: 0.1689
#     Matches with: carpet, Similarity: 0.1201
#   Token: shave, Matches Count: 260
#     Matches with: mitten, Similarity: 0.1437
#     Matches with: render, Similarity: 0.1118
#     Matches with: comb, Similarity: 0.1750
#   Token: floor, Matches Count: 156
#     Matches with: coverlet, Similarity: 0.1020
#     Matches with: ornament, Similarity: 0.1491
#     Matches with: necklac, Similarity: 0.2434
#   Token: screen, Matches Count: 100
#     Matches with: bouquet, Similarity: 0.2669
#     Matches with: eyeglass, Similarity: 0.1146
#     Matches with: embroideri, Similarity: 0.1033
#   Token: cruet, Matches Count: 247
#     Matches with: mitten, Similarity: 0.1054
#     Matches with: tray, Similarity: 0.1164
#     Matches with: shoe, Similarity: 0.1599
#   Token: drum, Matches Count: 90
#     Matches with: fob, Similarity: 0.1203
#     Matches with: bootjack, Similarity: 0.1330
#     Matches with: skate, Similarity: 0.1739
#   Token: bark, Matches Count: 54
#     Matches with: needlework, Similarity: 0.1009
#     Matches with: walk, Similarity: 0.2033
#     Matches with: card, Similarity: 0.2217
#   Token: asparagu, Matches Count: 13
#     Matches with: needlework, Similarity: 0.1131
#     Matches with: case, Similarity: 0.1424
#     Matches with: bootjack, Similarity: 0.1652
#   Token: buncher, Matches Count: 15
#     Matches with: fan, Similarity: 0.1468
#     Matches with: case, Similarity: 0.1288
#     Matches with: tray, Similarity: 0.1342
#   Token: goblet, Matches Count: 312
#     Matches with: bouquet, Similarity: 0.1130
#     Matches with: sampler, Similarity: 0.1513
#     Matches with: collar, Similarity: 0.1506
#   Token: wool, Matches Count: 144
#     Matches with: suspend, Similarity: 0.1233
#     Matches with: collar, Similarity: 0.1979
#     Matches with: ear, Similarity: 0.1698
#   Token: button, Matches Count: 294
#     Matches with: bouquet, Similarity: 0.1042
#     Matches with: comb, Similarity: 0.2034
#     Matches with: bootjack, Similarity: 0.1581
#   Token: peeler, Matches Count: 64
#     Matches with: glove, Similarity: 0.2213
#     Matches with: sampler, Similarity: 0.1399
#     Matches with: overs, Similarity: 0.1705
#   Token: gaug, Matches Count: 42
#     Matches with: render, Similarity: 0.2180
#     Matches with: eyeglass, Similarity: 0.1164
#     Matches with: comb, Similarity: 0.1077
#   Token: needlework, Matches Count: 104
#     Matches with: needlework, Similarity: 1.0000
#     Matches with: cane, Similarity: 0.1905
#     Matches with: walk, Similarity: 0.1833
#   Token: splint, Matches Count: 30
#     Matches with: bouquet, Similarity: 0.1425
#     Matches with: fob, Similarity: 0.1088
#     Matches with: overs, Similarity: 0.1689
#   Token: potato, Matches Count: 84
#     Matches with: glove, Similarity: 0.1244
#     Matches with: carpet, Similarity: 0.1428
#     Matches with: sampler, Similarity: 0.1032
#   Token: roaster, Matches Count: 80
#     Matches with: mitten, Similarity: 0.1248
#     Matches with: bootjack, Similarity: 0.1446
#     Matches with: muff, Similarity: 0.2486
#   Token: stick, Matches Count: 255
#     Matches with: bouquet, Similarity: 0.1277
#     Matches with: carpet, Similarity: 0.1446
#     Matches with: pocket, Similarity: 0.1173
#   Token: spectacl, Matches Count: 120
#     Matches with: case, Similarity: 0.2141
#     Matches with: skate, Similarity: 0.1363
#     Matches with: collar, Similarity: 0.1775
#   Token: beam, Matches Count: 38
#     Matches with: glove, Similarity: 0.1601
#     Matches with: sampler, Similarity: 0.1082
#     Matches with: case, Similarity: 0.2986
#   Token: plow, Matches Count: 70
#     Matches with: bootjack, Similarity: 0.1169
#     Matches with: ear, Similarity: 0.2426
#     Matches with: umbrella, Similarity: 0.1007
#   Token: adz, Matches Count: 90
#     Matches with: mitten, Similarity: 0.1366
#     Matches with: glove, Similarity: 0.1197
#     Matches with: fob, Similarity: 0.1422
#   Token: fruit, Matches Count: 198
#     Matches with: bouquet, Similarity: 0.1156
#     Matches with: card, Similarity: 0.1106
#     Matches with: umbrella, Similarity: 0.1005
#   Token: drill, Matches Count: 22
#     Matches with: glove, Similarity: 0.1814
#     Matches with: bouquet, Similarity: 0.1159
#     Matches with: render, Similarity: 0.1559
#   Token: majolica, Matches Count: 26
#     Matches with: glove, Similarity: 0.2547
#     Matches with: carpet, Similarity: 0.2093
#     Matches with: pocket, Similarity: 0.1639
#   Token: buttermold, Matches Count: 15
#     Matches with: mitten, Similarity: 0.1249
#     Matches with: skate, Similarity: 0.1276
#     Matches with: cuff, Similarity: 0.1236
#   Token: bouquet, Matches Count: 32
#     Matches with: bouquet, Similarity: 1.0000
#     Matches with: pocket, Similarity: 0.1869
#     Matches with: necklac, Similarity: 0.2000
#   Token: stretcher, Matches Count: 75
#     Matches with: suspend, Similarity: 0.2287
#     Matches with: needlework, Similarity: 0.1830
#     Matches with: overs, Similarity: 0.1409
#   Token: cuff, Matches Count: 187
#     Matches with: mitten, Similarity: 0.1185
#     Matches with: fob, Similarity: 0.2113
#     Matches with: cane, Similarity: 0.1030
#   Token: hide, Matches Count: 80
#     Matches with: case, Similarity: 0.1642
#     Matches with: comb, Similarity: 0.1279
#     Matches with: skate, Similarity: 0.1404
#   Token: muff, Matches Count: 57
#     Matches with: fob, Similarity: 0.1432
#     Matches with: walk, Similarity: 0.1369
#     Matches with: comb, Similarity: 0.1500
#   Token: scrimshaw, Matches Count: 192
#     Matches with: glove, Similarity: 0.1260
#     Matches with: bouquet, Similarity: 0.1041
#     Matches with: fob, Similarity: 0.1604
#   Token: cane, Matches Count: 135
#     Matches with: needlework, Similarity: 0.1905
#     Matches with: carpet, Similarity: 0.2117
#     Matches with: cane, Similarity: 1.0000
#   Token: umbrella, Matches Count: 126
#     Matches with: glove, Similarity: 0.1537
#     Matches with: carpet, Similarity: 0.1458
#     Matches with: sampler, Similarity: 0.1979
#   Token: blacksmith, Matches Count: 72
#     Matches with: render, Similarity: 0.1981
#     Matches with: collar, Similarity: 0.1334
#     Matches with: satchel, Similarity: 0.2191
#   Token: cork, Matches Count: 16
#     Matches with: needlework, Similarity: 0.1576
#     Matches with: pocket, Similarity: 0.1593
#     Matches with: render, Similarity: 0.1468
#   Token: compressor, Matches Count: 18
#     Matches with: suspend, Similarity: 0.1081
#     Matches with: mitten, Similarity: 0.1217
#     Matches with: fob, Similarity: 0.1422
#   Token: slicer, Matches Count: 16
#     Matches with: mitten, Similarity: 0.1298
#     Matches with: glove, Similarity: 0.2423
#     Matches with: carpet, Similarity: 0.1717
#   Token: sauerkraut, Matches Count: 12
#     Matches with: case, Similarity: 0.1068
#     Matches with: muff, Similarity: 0.1180
#     Matches with: cotton, Similarity: 0.1094
#   Token: stomper, Matches Count: 13
#     Matches with: carpet, Similarity: 0.2076
#     Matches with: comb, Similarity: 0.1219
#     Matches with: collar, Similarity: 0.1882
#   Token: economi, Matches Count: 266
#     Matches with: fob, Similarity: 0.1161
#     Matches with: needlework, Similarity: 0.1065
#     Matches with: ear, Similarity: 0.1309
#   Token: egg, Matches Count: 90
#     Matches with: mitten, Similarity: 0.1648
#     Matches with: overs, Similarity: 0.1997
#     Matches with: case, Similarity: 0.1085
#   Token: gourd, Matches Count: 26
#     Matches with: fan, Similarity: 0.1120
#     Matches with: ornament, Similarity: 0.1305
#     Matches with: brooch, Similarity: 0.1457
#   Token: glove, Matches Count: 204
#     Matches with: glove, Similarity: 1.0000
#     Matches with: sampler, Similarity: 0.3078
#     Matches with: render, Similarity: 0.1817
#   Token: garter, Matches Count: 51
#     Matches with: suspend, Similarity: 0.2341
#     Matches with: sampler, Similarity: 0.1189
#     Matches with: render, Similarity: 0.1346
#   Token: beater, Matches Count: 60
#     Matches with: overs, Similarity: 0.1975
#     Matches with: comb, Similarity: 0.1415
#     Matches with: collar, Similarity: 0.1683
#   Token: spreader, Matches Count: 9
#     Matches with: carpet, Similarity: 0.1328
#     Matches with: eyeglass, Similarity: 0.1653
#     Matches with: tray, Similarity: 0.1883
#   Token: appl, Matches Count: 165
#     Matches with: bouquet, Similarity: 0.1164
#     Matches with: fob, Similarity: 0.1131
#     Matches with: render, Similarity: 0.1038
#   Token: mixer, Matches Count: 54
#     Matches with: needlework, Similarity: 0.1314
#     Matches with: walk, Similarity: 0.1908
#     Matches with: fan, Similarity: 0.1131
#   Token: suppli, Matches Count: 19
#     Matches with: glove, Similarity: 0.1427
#     Matches with: sampler, Similarity: 0.2462
#     Matches with: comb, Similarity: 0.1090
#   Token: stage, Matches Count: 176
#     Matches with: glove, Similarity: 0.1569
#     Matches with: sampler, Similarity: 0.1894
#     Matches with: render, Similarity: 0.1363
#   Token: alarm, Matches Count: 5
#     Matches with: embroid, Similarity: 0.1085
#     Matches with: accessori, Similarity: 0.1284
#     Matches with: button, Similarity: 0.1643
#   Token: cranberri, Matches Count: 24
#     Matches with: glove, Similarity: 0.1465
#     Matches with: pocket, Similarity: 0.1972
#     Matches with: render, Similarity: 0.1046
#   Token: picker, Matches Count: 30
#     Matches with: eyeglass, Similarity: 0.1137
#     Matches with: comb, Similarity: 0.1358
#     Matches with: bootjack, Similarity: 0.2807
#   Token: snow, Matches Count: 72
#     Matches with: glove, Similarity: 0.2264
#     Matches with: fob, Similarity: 0.1344
#     Matches with: needlework, Similarity: 0.1005
#   Token: accessori, Matches Count: 72
#     Matches with: glove, Similarity: 0.1378
#     Matches with: sampler, Similarity: 0.1856
#     Matches with: render, Similarity: 0.1243
#   Token: bristl, Matches Count: 20
#     Matches with: muff, Similarity: 0.2881
#     Matches with: card, Similarity: 0.1549
#     Matches with: satchel, Similarity: 0.1047
#   Token: remov, Matches Count: 20
#     Matches with: comb, Similarity: 0.1178
#     Matches with: tray, Similarity: 0.1043
#     Matches with: parasol, Similarity: 0.1409
#   Token: utensil, Matches Count: 34
#     Matches with: mitten, Similarity: 0.1257
#     Matches with: carpet, Similarity: 0.1744
#     Matches with: walk, Similarity: 0.1368
#   Token: instrument, Matches Count: 16
#     Matches with: suspend, Similarity: 0.1073
#     Matches with: mitten, Similarity: 0.1001
#     Matches with: case, Similarity: 0.1555
#   Token: turpentin, Matches Count: 54
#     Matches with: glove, Similarity: 0.1937
#     Matches with: sampler, Similarity: 0.1352
#     Matches with: render, Similarity: 0.1073
#   Token: women, Matches Count: 70
#     Matches with: pocket, Similarity: 0.1171
#     Matches with: parasol, Similarity: 0.1573
#     Matches with: uniform, Similarity: 0.1026
#   Token: implement, Matches Count: 26
#     Matches with: suspend, Similarity: 0.1076
#     Matches with: pocket, Similarity: 0.1086
#     Matches with: eyeglass, Similarity: 0.1539
#   Token: chisel, Matches Count: 39
#     Matches with: fob, Similarity: 0.2144
#     Matches with: coverlet, Similarity: 0.1446
#     Matches with: satchel, Similarity: 0.2420
#   Token: muffin, Matches Count: 40
#     Matches with: sampler, Similarity: 0.1362
#     Matches with: card, Similarity: 0.1485
#     Matches with: jacquard, Similarity: 0.1515
#   Token: sharpen, Matches Count: 34
#     Matches with: mitten, Similarity: 0.1013
#     Matches with: carpet, Similarity: 0.1250
#     Matches with: render, Similarity: 0.1462
#   Token: bin, Matches Count: 30
#     Matches with: carpet, Similarity: 0.1558
#     Matches with: sampler, Similarity: 0.1177
#     Matches with: eyeglass, Similarity: 0.1028
#   Token: string, Matches Count: 64
#     Matches with: fob, Similarity: 0.1545
#     Matches with: cane, Similarity: 0.2464
#     Matches with: walk, Similarity: 0.2984
#   Token: shear, Matches Count: 30
#     Matches with: overs, Similarity: 0.1350
#     Matches with: case, Similarity: 0.1255
#     Matches with: bootjack, Similarity: 0.1579
#   Token: clog, Matches Count: 28
#     Matches with: fob, Similarity: 0.2315
#     Matches with: fan, Similarity: 0.2038
#     Matches with: necklac, Similarity: 0.1103
#   Token: cracker, Matches Count: 20
#     Matches with: mitten, Similarity: 0.1100
#     Matches with: embroid, Similarity: 0.1642
#     Matches with: brooch, Similarity: 0.1625
#   Token: trap, Matches Count: 30
#     Matches with: eyeglass, Similarity: 0.1001
#     Matches with: comb, Similarity: 0.1099
#     Matches with: collar, Similarity: 0.1133
#   Token: pill, Matches Count: 9
#     Matches with: cane, Similarity: 0.1501
#     Matches with: comb, Similarity: 0.1033
#     Matches with: parasol, Similarity: 0.1940
#   Token: coater, Matches Count: 15
#     Matches with: case, Similarity: 0.1121
#     Matches with: collar, Similarity: 0.1769
#     Matches with: satchel, Similarity: 0.2128
#   Token: brush, Matches Count: 84
#     Matches with: suspend, Similarity: 0.1205
#     Matches with: pocket, Similarity: 0.1127
#     Matches with: cane, Similarity: 0.1640
#   Token: equip, Matches Count: 15
#     Matches with: glove, Similarity: 0.1430
#     Matches with: fob, Similarity: 0.1605
#     Matches with: sampler, Similarity: 0.1928
#   Token: militari, Matches Count: 36
#     Matches with: fob, Similarity: 0.1475
#     Matches with: fan, Similarity: 0.2368
#     Matches with: collar, Similarity: 0.1547
#   Token: squeezer, Matches Count: 11
#     Matches with: walk, Similarity: 0.1497
#     Matches with: fan, Similarity: 0.1775
#     Matches with: case, Similarity: 0.1040
#   Token: grater, Matches Count: 30
#     Matches with: collar, Similarity: 0.1650
#     Matches with: muff, Similarity: 0.1073
#     Matches with: ear, Similarity: 0.1593
#   Token: human, Matches Count: 112
#     Matches with: bouquet, Similarity: 0.2074
#     Matches with: fob, Similarity: 0.1778
#     Matches with: needlework, Similarity: 0.1179
#   Token: petroglyph, Matches Count: 480
#     Matches with: mitten, Similarity: 0.1849
#     Matches with: glove, Similarity: 0.1405
#     Matches with: fob, Similarity: 0.1692
#   Token: spoke, Matches Count: 19
#     Matches with: suspend, Similarity: 0.1072
#     Matches with: carpet, Similarity: 0.1681
#     Matches with: pocket, Similarity: 0.1624
#   Token: mast, Matches Count: 24
#     Matches with: suspend, Similarity: 0.1117
#     Matches with: overs, Similarity: 0.1094
#     Matches with: comb, Similarity: 0.1447
#   Token: place, Matches Count: 17
#     Matches with: suspend, Similarity: 0.1086
#     Matches with: mitten, Similarity: 0.2182
#     Matches with: glove, Similarity: 0.1154
#   Token: planter, Matches Count: 38
#     Matches with: fob, Similarity: 0.1152
#     Matches with: cane, Similarity: 0.1086
#     Matches with: walk, Similarity: 0.1550
#   Token: lar, Matches Count: 10
#     Matches with: glove, Similarity: 0.1724
#     Matches with: render, Similarity: 0.2144
#     Matches with: eyeglass, Similarity: 0.1059
#   Token: frow, Matches Count: 26
#     Matches with: collar, Similarity: 0.1210
#     Matches with: spectacl, Similarity: 0.1413
#     Matches with: card, Similarity: 0.1212
#   Token: reamer, Matches Count: 12
#     Matches with: glove, Similarity: 0.1692
#     Matches with: bouquet, Similarity: 0.1822
#     Matches with: necklac, Similarity: 0.1596
#   Token: backdrop, Matches Count: 63
#     Matches with: needlework, Similarity: 0.1950
#     Matches with: fan, Similarity: 0.1018
#     Matches with: case, Similarity: 0.1776
#   Token: broom, Matches Count: 24
#     Matches with: fob, Similarity: 0.1870
#     Matches with: carpet, Similarity: 0.1401
#     Matches with: bootjack, Similarity: 0.1785
#   Token: industri, Matches Count: 36
#     Matches with: sampler, Similarity: 0.1706
#     Matches with: overs, Similarity: 0.1150
#     Matches with: muff, Similarity: 0.1381
#   Token: crimper, Matches Count: 20
#     Matches with: sampler, Similarity: 0.2154
#     Matches with: eyeglass, Similarity: 0.1503
#     Matches with: skate, Similarity: 0.1066
#   Token: sachet, Matches Count: 13
#     Matches with: glove, Similarity: 0.1397
#     Matches with: needlework, Similarity: 0.1526
#     Matches with: carpet, Similarity: 0.1943
#   Token: hatchet, Matches Count: 17
#     Matches with: walk, Similarity: 0.1625
#     Matches with: comb, Similarity: 0.1092
#     Matches with: spectacl, Similarity: 0.1429
#   Token: dayb, Matches Count: 14
#     Matches with: fob, Similarity: 0.1826
#     Matches with: render, Similarity: 0.1794
#     Matches with: comb, Similarity: 0.2033
#   Token: rake, Matches Count: 22
#     Matches with: collar, Similarity: 0.1965
#     Matches with: spectacl, Similarity: 0.1092
#     Matches with: necklac, Similarity: 0.1984
#   Token: freezer, Matches Count: 10
#     Matches with: collar, Similarity: 0.1041
#     Matches with: card, Similarity: 0.1990
#     Matches with: satchel, Similarity: 0.1508
#   Token: clam, Matches Count: 13
#     Matches with: suspend, Similarity: 0.1043
#     Matches with: needlework, Similarity: 0.1105
#     Matches with: walk, Similarity: 0.1372

# %%
# Check the number of unique object IDs per token
unique_check = {}
for section, tokens in similarity_dict.items():
    for token, entries in tokens.items():
        if token not in unique_check:
            unique_check[token] = set()
        unique_check[token].update([entry['object_id'] for entry in entries])

# Print out the results
for token, object_ids in unique_check.items():
    print(f"Token: {token}, Unique Object IDs: {len(object_ids)}")
# Out:
# Token: wallpap, Unique Object IDs: 49
# Token: bit, Unique Object IDs: 57
# Token: dirk, Unique Object IDs: 2
# Token: candl, Unique Object IDs: 136
# Token: holder, Unique Object IDs: 190
# Token: doorway, Unique Object IDs: 103
# Token: door, Unique Object IDs: 140
# Token: restor, Unique Object IDs: 41
# Token: draw, Unique Object IDs: 67
# Token: grandfath, Unique Object IDs: 40
# Token: clock, Unique Object IDs: 227
# Token: tripod, Unique Object IDs: 6
# Token: tabl, Unique Object IDs: 385
# Token: ring, Unique Object IDs: 34
# Token: bottl, Unique Object IDs: 155
# Token: indian, Unique Object IDs: 246
# Token: ladl, Unique Object IDs: 35
# Token: sugar, Unique Object IDs: 173
# Token: bowl, Unique Object IDs: 264
# Token: cover, Unique Object IDs: 124
# Token: glass, Unique Object IDs: 212
# Token: lamp, Unique Object IDs: 347
# Token: chamber, Unique Object IDs: 3
# Token: spark, Unique Object IDs: 12
# Token: pewter, Unique Object IDs: 273
# Token: coffe, Unique Object IDs: 110
# Token: pot, Unique Object IDs: 141
# Token: mug, Unique Object IDs: 162
# Token: porring, Unique Object IDs: 61
# Token: tankard, Unique Object IDs: 91
# Token: quilt, Unique Object IDs: 480
# Token: appliqu, Unique Object IDs: 91
# Token: coverlet, Unique Object IDs: 337
# Token: embroideri, Unique Object IDs: 69
# Token: decor, Unique Object IDs: 196
# Token: pitcher, Unique Object IDs: 368
# Token: silver, Unique Object IDs: 682
# Token: knife, Unique Object IDs: 56
# Token: fork, Unique Object IDs: 30
# Token: wall, Unique Object IDs: 311
# Token: cherri, Unique Object IDs: 10
# Token: satchel, Unique Object IDs: 2
# Token: iron, Unique Object IDs: 516
# Token: wood, Unique Object IDs: 71
# Token: carv, Unique Object IDs: 158
# Token: copper, Unique Object IDs: 37
# Token: kettl, Unique Object IDs: 61
# Token: desk, Unique Object IDs: 143
# Token: american, Unique Object IDs: 15
# Token: teapot, Unique Object IDs: 153
# Token: dress, Unique Object IDs: 533
# Token: uniform, Unique Object IDs: 10
# Token: german, Unique Object IDs: 534
# Token: earthenwar, Unique Object IDs: 18
# Token: bird, Unique Object IDs: 47
# Token: churn, Unique Object IDs: 47
# Token: cup, Unique Object IDs: 96
# Token: pennsylvania, Unique Object IDs: 80
# Token: ornament, Unique Object IDs: 77
# Token: hors, Unique Object IDs: 153
# Token: salt, Unique Object IDs: 66
# Token: print, Unique Object IDs: 134
# Token: mold, Unique Object IDs: 150
# Token: shoe, Unique Object IDs: 121
# Token: chest, Unique Object IDs: 308
# Token: chair, Unique Object IDs: 597
# Token: pastri, Unique Object IDs: 3
# Token: shaker, Unique Object IDs: 327
# Token: stove, Unique Object IDs: 82
# Token: dipper, Unique Object IDs: 11
# Token: coat, Unique Object IDs: 83
# Token: suit, Unique Object IDs: 66
# Token: carpet, Unique Object IDs: 37
# Token: box, Unique Object IDs: 244
# Token: cooki, Unique Object IDs: 10
# Token: cutter, Unique Object IDs: 22
# Token: bishop, Unique Object IDs: 51
# Token: hill, Unique Object IDs: 51
# Token: bell, Unique Object IDs: 68
# Token: cigar, Unique Object IDs: 237
# Token: store, Unique Object IDs: 251
# Token: sampler, Unique Object IDs: 53
# Token: detail, Unique Object IDs: 144
# Token: pictur, Unique Object IDs: 40
# Token: eagl, Unique Object IDs: 106
# Token: panel, Unique Object IDs: 54
# Token: rug, Unique Object IDs: 83
# Token: fan, Unique Object IDs: 19
# Token: collar, Unique Object IDs: 44
# Token: garden, Unique Object IDs: 53
# Token: bench, Unique Object IDs: 50
# Token: bed, Unique Object IDs: 96
# Token: tub, Unique Object IDs: 13
# Token: jack, Unique Object IDs: 22
# Token: figur, Unique Object IDs: 152
# Token: work, Unique Object IDs: 23
# Token: machin, Unique Object IDs: 6
# Token: hardwar, Unique Object IDs: 4
# Token: costum, Unique Object IDs: 32
# Token: ear, Unique Object IDs: 37
# Token: stool, Unique Object IDs: 23
# Token: grinder, Unique Object IDs: 26
# Token: toy, Unique Object IDs: 220
# Token: set, Unique Object IDs: 19
# Token: compot, Unique Object IDs: 35
# Token: post, Unique Object IDs: 89
# Token: tray, Unique Object IDs: 67
# Token: spur, Unique Object IDs: 94
# Token: form, Unique Object IDs: 4
# Token: bootjack, Unique Object IDs: 46
# Token: metal, Unique Object IDs: 28
# Token: fireplac, Unique Object IDs: 27
# Token: shovel, Unique Object IDs: 27
# Token: hay, Unique Object IDs: 9
# Token: railway, Unique Object IDs: 1
# Token: pail, Unique Object IDs: 10
# Token: pick, Unique Object IDs: 1
# Token: plane, Unique Object IDs: 22
# Token: cloth, Unique Object IDs: 28
# Token: yoke, Unique Object IDs: 16
# Token: wrench, Unique Object IDs: 2
# Token: decoy, Unique Object IDs: 27
# Token: fish, Unique Object IDs: 20
# Token: spear, Unique Object IDs: 4
# Token: cradl, Unique Object IDs: 51
# Token: sofa, Unique Object IDs: 64
# Token: cotton, Unique Object IDs: 81
# Token: marker, Unique Object IDs: 13
# Token: paint, Unique Object IDs: 181
# Token: religi, Unique Object IDs: 4
# Token: design, Unique Object IDs: 297
# Token: bandbox, Unique Object IDs: 129
# Token: cemeteri, Unique Object IDs: 1
# Token: music, Unique Object IDs: 8
# Token: skate, Unique Object IDs: 13
# Token: corn, Unique Object IDs: 14
# Token: hitch, Unique Object IDs: 62
# Token: sheath, Unique Object IDs: 10
# Token: sausag, Unique Object IDs: 8
# Token: stuffer, Unique Object IDs: 5
# Token: funnel, Unique Object IDs: 4
# Token: roll, Unique Object IDs: 12
# Token: pin, Unique Object IDs: 59
# Token: ship, Unique Object IDs: 43
# Token: saw, Unique Object IDs: 9
# Token: case, Unique Object IDs: 57
# Token: shoemak, Unique Object IDs: 5
# Token: furnitur, Unique Object IDs: 9
# Token: stern, Unique Object IDs: 31
# Token: piec, Unique Object IDs: 75
# Token: sign, Unique Object IDs: 82
# Token: shop, Unique Object IDs: 33
# Token: skewer, Unique Object IDs: 7
# Token: comb, Unique Object IDs: 44
# Token: devic, Unique Object IDs: 2
# Token: washer, Unique Object IDs: 1
# Token: clamp, Unique Object IDs: 5
# Token: leather, Unique Object IDs: 27
# Token: bucket, Unique Object IDs: 36
# Token: hook, Unique Object IDs: 66
# Token: club, Unique Object IDs: 4
# Token: mallet, Unique Object IDs: 3
# Token: build, Unique Object IDs: 7
# Token: firemark, Unique Object IDs: 20
# Token: belt, Unique Object IDs: 15
# Token: auger, Unique Object IDs: 7
# Token: basket, Unique Object IDs: 56
# Token: brace, Unique Object IDs: 9
# Token: brand, Unique Object IDs: 76
# Token: masher, Unique Object IDs: 7
# Token: grain, Unique Object IDs: 17
# Token: pestl, Unique Object IDs: 26
# Token: scoop, Unique Object IDs: 13
# Token: figurehead, Unique Object IDs: 136
# Token: necklac, Unique Object IDs: 11
# Token: billet, Unique Object IDs: 4
# Token: room, Unique Object IDs: 30
# Token: cabinet, Unique Object IDs: 70
# Token: cupboard, Unique Object IDs: 80
# Token: secretari, Unique Object IDs: 31
# Token: measur, Unique Object IDs: 12
# Token: rattl, Unique Object IDs: 17
# Token: spoon, Unique Object IDs: 109
# Token: pocket, Unique Object IDs: 19
# Token: lowboy, Unique Object IDs: 22
# Token: mirror, Unique Object IDs: 81
# Token: sette, Unique Object IDs: 45
# Token: pan, Unique Object IDs: 34
# Token: tolewar, Unique Object IDs: 84
# Token: trouser, Unique Object IDs: 16
# Token: jacquard, Unique Object IDs: 9
# Token: woven, Unique Object IDs: 60
# Token: board, Unique Object IDs: 31
# Token: stencil, Unique Object IDs: 54
# Token: skimmer, Unique Object IDs: 6
# Token: art, Unique Object IDs: 131
# Token: spanish, Unique Object IDs: 224
# Token: california, Unique Object IDs: 90
# Token: purs, Unique Object IDs: 46
# Token: quaker, Unique Object IDs: 26
# Token: textil, Unique Object IDs: 109
# Token: linen, Unique Object IDs: 43
# Token: tool, Unique Object IDs: 15
# Token: game, Unique Object IDs: 8
# Token: rig, Unique Object IDs: 3
# Token: saddl, Unique Object IDs: 46
# Token: sideboard, Unique Object IDs: 19
# Token: interior, Unique Object IDs: 20
# Token: hammer, Unique Object IDs: 9
# Token: tong, Unique Object IDs: 42
# Token: highboy, Unique Object IDs: 35
# Token: car, Unique Object IDs: 12
# Token: spatula, Unique Object IDs: 4
# Token: four, Unique Object IDs: 11
# Token: architectur, Unique Object IDs: 12
# Token: silk, Unique Object IDs: 50
# Token: hair, Unique Object IDs: 26
# Token: whirligig, Unique Object IDs: 17
# Token: map, Unique Object IDs: 5
# Token: sculptur, Unique Object IDs: 2
# Token: embroid, Unique Object IDs: 75
# Token: light, Unique Object IDs: 17
# Token: render, Unique Object IDs: 3
# Token: chalkwar, Unique Object IDs: 53
# Token: gavel, Unique Object IDs: 1
# Token: zoar, Unique Object IDs: 57
# Token: mitt, Unique Object IDs: 9
# Token: suspend, Unique Object IDs: 5
# Token: card, Unique Object IDs: 46
# Token: mortar, Unique Object IDs: 30
# Token: bracelet, Unique Object IDs: 20
# Token: drain, Unique Object IDs: 3
# Token: piggin, Unique Object IDs: 3
# Token: well, Unique Object IDs: 7
# Token: mitten, Unique Object IDs: 5
# Token: wallet, Unique Object IDs: 4
# Token: stamp, Unique Object IDs: 14
# Token: flail, Unique Object IDs: 4
# Token: axe, Unique Object IDs: 18
# Token: pitter, Unique Object IDs: 3
# Token: mill, Unique Object IDs: 12
# Token: waist, Unique Object IDs: 9
# Token: cream, Unique Object IDs: 44
# Token: scraper, Unique Object IDs: 27
# Token: settl, Unique Object IDs: 3
# Token: southwest, Unique Object IDs: 4
# Token: amana, Unique Object IDs: 6
# Token: hoe, Unique Object IDs: 7
# Token: flour, Unique Object IDs: 5
# Token: sifter, Unique Object IDs: 4
# Token: men, Unique Object IDs: 5
# Token: trailboard, Unique Object IDs: 2
# Token: anim, Unique Object IDs: 8
# Token: brooch, Unique Object IDs: 69
# Token: buckl, Unique Object IDs: 31
# Token: watch, Unique Object IDs: 37
# Token: fob, Unique Object IDs: 6
# Token: walk, Unique Object IDs: 13
# Token: keg, Unique Object IDs: 9
# Token: crewel, Unique Object IDs: 43
# Token: stock, Unique Object IDs: 19
# Token: apron, Unique Object IDs: 24
# Token: nut, Unique Object IDs: 4
# Token: barrel, Unique Object IDs: 6
# Token: piano, Unique Object IDs: 18
# Token: handbag, Unique Object IDs: 10
# Token: parasol, Unique Object IDs: 16
# Token: jewelri, Unique Object IDs: 8
# Token: ice, Unique Object IDs: 14
# Token: pipe, Unique Object IDs: 22
# Token: dough, Unique Object IDs: 14
# Token: ceram, Unique Object IDs: 6
# Token: shave, Unique Object IDs: 26
# Token: floor, Unique Object IDs: 12
# Token: screen, Unique Object IDs: 20
# Token: cruet, Unique Object IDs: 19
# Token: drum, Unique Object IDs: 6
# Token: bark, Unique Object IDs: 6
# Token: asparagu, Unique Object IDs: 1
# Token: buncher, Unique Object IDs: 1
# Token: goblet, Unique Object IDs: 26
# Token: wool, Unique Object IDs: 16
# Token: button, Unique Object IDs: 21
# Token: peeler, Unique Object IDs: 4
# Token: gaug, Unique Object IDs: 3
# Token: needlework, Unique Object IDs: 8
# Token: splint, Unique Object IDs: 2
# Token: potato, Unique Object IDs: 6
# Token: roaster, Unique Object IDs: 5
# Token: stick, Unique Object IDs: 15
# Token: spectacl, Unique Object IDs: 8
# Token: beam, Unique Object IDs: 2
# Token: plow, Unique Object IDs: 7
# Token: adz, Unique Object IDs: 5
# Token: fruit, Unique Object IDs: 22
# Token: drill, Unique Object IDs: 2
# Token: majolica, Unique Object IDs: 2
# Token: buttermold, Unique Object IDs: 3
# Token: bouquet, Unique Object IDs: 2
# Token: stretcher, Unique Object IDs: 5
# Token: cuff, Unique Object IDs: 11
# Token: hide, Unique Object IDs: 8
# Token: muff, Unique Object IDs: 3
# Token: scrimshaw, Unique Object IDs: 8
# Token: cane, Unique Object IDs: 9
# Token: umbrella, Unique Object IDs: 9
# Token: blacksmith, Unique Object IDs: 6
# Token: cork, Unique Object IDs: 1
# Token: compressor, Unique Object IDs: 1
# Token: slicer, Unique Object IDs: 1
# Token: sauerkraut, Unique Object IDs: 1
# Token: stomper, Unique Object IDs: 1
# Token: economi, Unique Object IDs: 19
# Token: egg, Unique Object IDs: 10
# Token: gourd, Unique Object IDs: 2
# Token: glove, Unique Object IDs: 12
# Token: garter, Unique Object IDs: 3
# Token: beater, Unique Object IDs: 4
# Token: spreader, Unique Object IDs: 1
# Token: appl, Unique Object IDs: 11
# Token: mixer, Unique Object IDs: 3
# Token: suppli, Unique Object IDs: 1
# Token: stage, Unique Object IDs: 11
# Token: alarm, Unique Object IDs: 1
# Token: cranberri, Unique Object IDs: 2
# Token: picker, Unique Object IDs: 2
# Token: snow, Unique Object IDs: 4
# Token: accessori, Unique Object IDs: 4
# Token: bristl, Unique Object IDs: 2
# Token: remov, Unique Object IDs: 1
# Token: utensil, Unique Object IDs: 2
# Token: instrument, Unique Object IDs: 1
# Token: turpentin, Unique Object IDs: 3
# Token: women, Unique Object IDs: 5
# Token: implement, Unique Object IDs: 2
# Token: chisel, Unique Object IDs: 3
# Token: muffin, Unique Object IDs: 5
# Token: sharpen, Unique Object IDs: 2
# Token: bin, Unique Object IDs: 2
# Token: string, Unique Object IDs: 4
# Token: shear, Unique Object IDs: 2
# Token: clog, Unique Object IDs: 2
# Token: cracker, Unique Object IDs: 2
# Token: trap, Unique Object IDs: 3
# Token: pill, Unique Object IDs: 1
# Token: coater, Unique Object IDs: 1
# Token: brush, Unique Object IDs: 4
# Token: equip, Unique Object IDs: 1
# Token: militari, Unique Object IDs: 2
# Token: squeezer, Unique Object IDs: 1
# Token: grater, Unique Object IDs: 2
# Token: human, Unique Object IDs: 8
# Token: petroglyph, Unique Object IDs: 30
# Token: spoke, Unique Object IDs: 1
# Token: mast, Unique Object IDs: 2
# Token: place, Unique Object IDs: 1
# Token: planter, Unique Object IDs: 2
# Token: lar, Unique Object IDs: 1
# Token: frow, Unique Object IDs: 1
# Token: reamer, Unique Object IDs: 1
# Token: backdrop, Unique Object IDs: 3
# Token: broom, Unique Object IDs: 2
# Token: industri, Unique Object IDs: 2
# Token: crimper, Unique Object IDs: 1
# Token: sachet, Unique Object IDs: 1
# Token: hatchet, Unique Object IDs: 1
# Token: dayb, Unique Object IDs: 1
# Token: rake, Unique Object IDs: 2
# Token: freezer, Unique Object IDs: 1
# Token: clam, Unique Object IDs: 1

# %%
# Example to limit the number of tokens processed for printing
max_tokens_to_print = 10  # Set a reasonable limit
count = 0

for section, tokens in similarity_dict.items():
    for token, entries in tokens.items():
        if count >= max_tokens_to_print:
            break
        print(f"Section: {section}, Token: {token}")
        for entry in entries[:5]:  # Limit the number of entries per token to print
            print(f"  Object ID: {entry['object_id']}, Title Text: {entry['title_text']}")
            print(f"  Matched Token: {entry['section_token']}, Similarity: {entry['similarity']:.4f}")
        count += 1
        print("---")  # Separator for clarity
    if count >= max_tokens_to_print:
        break
# Out:
# Section: Textiles Costume and Jewelry, Token: wallpap
#   Object ID: 29580, Title Text: Wallpaper
#   Matched Token: fan, Similarity: 0.2568
#   Object ID: 29580, Title Text: Wallpaper
#   Matched Token: uniform, Similarity: 0.1045
#   Object ID: 29580, Title Text: Wallpaper
#   Matched Token: pictur, Similarity: 0.1005
#   Object ID: 29580, Title Text: Wallpaper
#   Matched Token: clog, Similarity: 0.1385
#   Object ID: 29580, Title Text: Wallpaper
#   Matched Token: waist, Similarity: 0.1442
# ---
# Section: Textiles Costume and Jewelry, Token: bit
#   Object ID: 26713, Title Text: Bit
#   Matched Token: pocket, Similarity: 0.1487
#   Object ID: 26713, Title Text: Bit
#   Matched Token: walk, Similarity: 0.1654
#   Object ID: 26713, Title Text: Bit
#   Matched Token: ear, Similarity: 0.1046
#   Object ID: 26713, Title Text: Bit
#   Matched Token: children, Similarity: 0.1674
#   Object ID: 26713, Title Text: Bit
#   Matched Token: cuff, Similarity: 0.1781
# ---
# Section: Textiles Costume and Jewelry, Token: dirk
#   Object ID: 29441, Title Text: Dirk
#   Matched Token: bouquet, Similarity: 0.2088
#   Object ID: 29441, Title Text: Dirk
#   Matched Token: bootjack, Similarity: 0.1190
#   Object ID: 29441, Title Text: Dirk
#   Matched Token: collar, Similarity: 0.1194
#   Object ID: 29441, Title Text: Dirk
#   Matched Token: ear, Similarity: 0.1149
#   Object ID: 29441, Title Text: Dirk
#   Matched Token: ornament, Similarity: 0.1457
# ---
# Section: Textiles Costume and Jewelry, Token: candl
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: eyeglass, Similarity: 0.1279
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: muff, Similarity: 0.1171
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: ear, Similarity: 0.1663
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: form, Similarity: 0.1373
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: spur, Similarity: 0.1572
# ---
# Section: Textiles Costume and Jewelry, Token: holder
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: suspend, Similarity: 0.2137
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: carpet, Similarity: 0.1646
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: pocket, Similarity: 0.1824
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: cane, Similarity: 0.1971
#   Object ID: 29740, Title Text: Candle Holder
#   Matched Token: comb, Similarity: 0.1020
# ---
# Section: Textiles Costume and Jewelry, Token: doorway
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: needlework, Similarity: 0.1882
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: render, Similarity: 0.1140
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: coverlet, Similarity: 0.1504
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: cotton, Similarity: 0.2072
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: children, Similarity: 0.1188
# ---
# Section: Textiles Costume and Jewelry, Token: door
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: mitten, Similarity: 0.1253
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: bouquet, Similarity: 0.2934
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: fan, Similarity: 0.1706
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: tray, Similarity: 0.2463
#   Object ID: 29814, Title Text: Doorway and Doors
#   Matched Token: parasol, Similarity: 0.1648
# ---
# Section: Textiles Costume and Jewelry, Token: restor
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: glove, Similarity: 0.1047
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: carpet, Similarity: 0.2876
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: pocket, Similarity: 0.1679
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: case, Similarity: 0.1414
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: card, Similarity: 0.2574
# ---
# Section: Textiles Costume and Jewelry, Token: draw
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: sampler, Similarity: 0.1129
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: walk, Similarity: 0.1827
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: case, Similarity: 0.1392
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: comb, Similarity: 0.1934
#   Object ID: 29936, Title Text: Restoration Drawing
#   Matched Token: card, Similarity: 0.1129
# ---
# Section: Textiles Costume and Jewelry, Token: grandfath
#   Object ID: 17059, Title Text: Grandfather Clock
#   Matched Token: render, Similarity: 0.1526
#   Object ID: 17059, Title Text: Grandfather Clock
#   Matched Token: walk, Similarity: 0.1089
#   Object ID: 17059, Title Text: Grandfather Clock
#   Matched Token: case, Similarity: 0.1457
#   Object ID: 17059, Title Text: Grandfather Clock
#   Matched Token: tray, Similarity: 0.1081
#   Object ID: 17059, Title Text: Grandfather Clock
#   Matched Token: parasol, Similarity: 0.2423
# ---

# %% [markdown]
# ***

# %% [markdown]
# ### Organize Data by Token and Section

# %%
# Initialize a nested dictionary to organize data by token, then by section
token_section_matches = defaultdict(lambda: defaultdict(list))

for result in similarity_results:
    token = result['title_token']
    section = result['section_name']
    # Only include results with a positive similarity or above a certain threshold
    if result['similarity'] > 0.33:
        token_section_matches[token][section].append({
            'matched_token': result['section_token'],
            'similarity': result['similarity'],
            'object_id': result['object_id'],
            'title_text': result['title_text'],
            'section_id': result['section_id']
        })

# %%
# Print a sample of the organized data
for token, sections in list(token_section_matches.items())[:5]:  # Limit to first 5 tokens for demonstration
    print(f"Token: {token}")
    for section, matches in sections.items():
        print(f"  Section: {section}, Matches Count: {len(matches)}")
        for match in matches[:3]:  # Show only the first 3 matches for brevity
            print(f"    Matches with: {match['matched_token']}, Similarity: {match['similarity']:.4f}")
        print("---")
# Out:
# Token: wallpap
#   Section: Architecture and Naive Art, Matches Count: 49
#     Matches with: wallpap, Similarity: 1.0000
#     Matches with: wallpap, Similarity: 1.0000
#     Matches with: wallpap, Similarity: 1.0000
# ---
# Token: bit
#   Section: The Art and Design of Utopian and Religious Communities, Matches Count: 57
#     Matches with: bit, Similarity: 1.0000
#     Matches with: bit, Similarity: 1.0000
#     Matches with: bit, Similarity: 1.0000
# ---
#   Section: Tools Hardware Firearms and Vehicles, Matches Count: 57
#     Matches with: bit, Similarity: 1.0000
#     Matches with: bit, Similarity: 1.0000
#     Matches with: bit, Similarity: 1.0000
# ---
# Token: holder
#   Section: Textiles Costume and Jewelry, Matches Count: 190
#     Matches with: holder, Similarity: 1.0000
#     Matches with: holder, Similarity: 1.0000
#     Matches with: holder, Similarity: 1.0000
# ---
#   Section: Domestic Utensils, Matches Count: 190
#     Matches with: holder, Similarity: 1.0000
#     Matches with: holder, Similarity: 1.0000
#     Matches with: holder, Similarity: 1.0000
# ---
# Token: door
#   Section: The Art and Design of Utopian and Religious Communities, Matches Count: 142
#     Matches with: religi, Similarity: 0.3486
#     Matches with: religi, Similarity: 0.3486
#     Matches with: religi, Similarity: 0.3486
# ---
#   Section: Wood Carvings and Weathervanes, Matches Count: 142
#     Matches with: religi, Similarity: 0.3486
#     Matches with: religi, Similarity: 0.3486
#     Matches with: religi, Similarity: 0.3486
# ---
# Token: clock
#   Section: The Art and Design of Utopian and Religious Communities, Matches Count: 230
#     Matches with: clock, Similarity: 1.0000
#     Matches with: clock, Similarity: 1.0000
#     Matches with: clock, Similarity: 1.0000
# ---

# %%
# Write to CSV for detailed analysis
import csv

with open('token_section_matches.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Token', 'Section', 'Matched Token', 'Similarity', 'Object ID', 'Title Text', 'Section ID'])
    for token, sections in token_section_matches.items():
        for section, matches in sections.items():
            for match in matches:
                writer.writerow([token, section, match['matched_token'], match['similarity'], match['object_id'], match['title_text'], match['section_id']])

# %% [markdown]
# ## Alt approach (by object id with multiple tokens)

# %%
# Assuming similarity_results has been loaded and contains entries with object_id
similarity_dict = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

for result in similarity_results:
    object_id = result['object_id']
    token = result['title_token']
    section = result['section_name']
    section_id = result['section_id']
    if result['similarity'] > 0.33:  # Include only positive similarity scores
        entry = {
            'matched_token': result['section_token'],
            'similarity': result['similarity'],
            'section_id': result['section_id'],
            'section_name': section,
            'section_id': section_id
        }
        similarity_dict[object_id][token][section].append(entry)

# Optionally, transform this into a more compact format if needed

# %%
# Example of how to print this structure for a sample object
sample_object_id = 29580  # Example object ID
if sample_object_id in similarity_dict:
    for section, tokens in similarity_dict[sample_object_id].items():
        print(f"Object ID: {sample_object_id}, Section: {section}")
        for token, details in tokens.items():
            print(f"  Token: {token}")
            for detail in details:
                print(f"    Matches with: {detail['matched_token']}, Similarity: {detail['similarity']:.4f}")
else:
    print(f"No similarity data available for Object ID: {sample_object_id}")
# Out:
# Object ID: 29580, Section: wallpap
#   Token: Architecture and Naive Art
#     Matches with: wallpap, Similarity: 1.0000

# %%
# Load title tokens data
with open('data/title_tokens_clean.json', 'r') as file:
    title_tokens_data = json.load(file)

# Append structured similarity results to each title based on object_id
for title in title_tokens_data:
    object_id = title['object_id']
    title['similarity_results'] = similarity_dict[object_id] if object_id in similarity_dict else {}

# Print the structured data for a sample of titles
for title in title_tokens_data[:5]:  # Limit to the first five titles for clarity
    print(f"Title: {title['title']} (Object ID: {title['object_id']})")
    tokens = title.get('tokens', [])
    for token in tokens:
        print(f"  Token: {token}")
        token_sections = title['similarity_results'].get(token, {})
        for section, matches in token_sections.items():
            print(f"    Section: {section} (Section Id: {matches[0]['section_id'] if matches else 'N/A'})")
            for match in matches:
                print(f"      Matches with: {match['matched_token']}, Similarity: {match['similarity']:.4f}")
    print("---")
# Out:
# Title: Wallpaper (Object ID: 29580)
#   Token: wallpap
#     Section: Architecture and Naive Art (Section Id: 2)
#       Matches with: wallpap, Similarity: 1.0000
# ---
# Title: Bit (Object ID: 26713)
#   Token: bit
#     Section: The Art and Design of Utopian and Religious Communities (Section Id: 1)
#       Matches with: bit, Similarity: 1.0000
#     Section: Tools Hardware Firearms and Vehicles (Section Id: 3)
#       Matches with: bit, Similarity: 1.0000
# ---
# Title: Dirk (Object ID: 29441)
#   Token: dirk
# ---
# Title: Candle Holder (Object ID: 29740)
#   Token: candl
#   Token: holder
#     Section: Textiles Costume and Jewelry (Section Id: 0)
#       Matches with: holder, Similarity: 1.0000
#     Section: Domestic Utensils (Section Id: 4)
#       Matches with: holder, Similarity: 1.0000
# ---
# Title: Doorway and Doors (Object ID: 29814)
#   Token: door
#     Section: The Art and Design of Utopian and Religious Communities (Section Id: 1)
#       Matches with: religi, Similarity: 0.3486
#     Section: Wood Carvings and Weathervanes (Section Id: 6)
#       Matches with: religi, Similarity: 0.3486
#   Token: doorway
# ---

# %% [markdown]
# ***

# %% [markdown]
# ### Export

# %%
# Optionally, save the updated data back to JSON
output_file_path = './data/token_section_similarity_match.json'

# with open(output_path, 'w') as file:
#     json.dump(title_tokens_data, file, indent=4)
# print(f"Data enriched with similarity results has been saved to {output_path}")

# Open the file in write mode and use json.dump to serialize the data to JSON and write it to the file
try:
    with open(output_file_path, 'w', encoding='utf-8') as file:
        json.dump(title_tokens_data, file, indent=4, ensure_ascii=False)  # Using indent for pretty-printing
    print(f"Data successfully saved to {output_file_path}")
except Exception as e:
    print(f"An error occurred while writing to the file: {e}")
# Out:
# Data successfully saved to ./data/token_section_similarity_match.json

# %%
num_results = len(title_tokens_data)

print(num_results)
# Out:
# 18259
