# %% [markdown]
# # Matching Section Tokens back to Catalog

# %%
import json

# %%
def extract_tokens(data):
    tokens = []
    for item in data:
        if "tokens" in item:
            tokens.extend(item["tokens"])
    return tokens

# %%
# # Example usage for confirming tokens and count
# json1_file = 'cleaned_sections_tokens.json'

# # Load JSON data
# with open(json1_file, 'r') as f1:
#     data1 = json.load(f1)

# # Extract tokens from JSON data
# tokens1 = extract_tokens(data1)

# # # Print the tokens
# # print("Tokens:")
# # for token in tokens1:
# #     print(token)

# # Count the number of tokens
# tokens_count = len(tokens1)

# # Print the number of tokens
# print("Number of tokens total:", tokens_count)

# # Now you can continue with the rest of your code to match tokens and words.
# Out:
# Number of tokens total: 496

# %%
def extract_words_at_level(data, level):
    if level == 1:
        return list(data.keys())
    words = []
    for key, value in data.items():
        if isinstance(value, dict):
            if level > 2:
                words.extend(extract_words_at_level(value, level - 1))
            elif level == 2:
                words.append(key)
        else:
            words.append(key)
    return words

# %%
# # DISPLAY MATCHING WORDS
# def extract_words_at_level(data, level):
#     if level == 1:
#         print("Words at level 1:")
#         print(list(data.keys()))
#     else:
#         print("Words at level", level, ":")
#         _extract_words_at_level(data, level, 1)

# def _extract_words_at_level(data, level, current_level):
#     for key, value in data.items():
#         if current_level == level:
#             print(key)
#         if isinstance(value, dict):
#             if current_level < level:
#                 _extract_words_at_level(value, level, current_level + 1)
                
# # Example usage
# json2_file = 'catalog_nested.json'
# level_to_check = 4  # Specify the level you want to check

# # Load JSON data
# with open(json2_file, 'r') as f2:
#     data2 = json.load(f2)

# # Display words from the specified level
# extract_words_at_level(data2, level_to_check)

# %%
def match_tokens(json1, json2, level):
    # Load JSON data
    with open(json1, 'r') as f1, open(json2, 'r') as f2:
        data1 = json.load(f1)
        data2 = json.load(f2)

    # Extract tokens/words from JSON data
    tokens1 = extract_tokens(data1)
    words2 = extract_words_at_level(data2, level)

    # Match tokens to words
    matched_pairs = []
    for token in tokens1:
        for word in words2:
            if token == word:
                matched_pairs.append((token, word))
                break  # Break once a match is found to avoid duplicate matches

    return matched_pairs

# %%
# Example usage
json1_file = 'cleaned_sections_tokens.json'
json2_file = 'catalog_nested.json'
level_to_check = 3  # Specify the level you want to check
matched_pairs = match_tokens(json1_file, json2_file, level_to_check)
matched_pairs_count = len(matched_pairs)
print("Matched pairs at level", level_to_check, ":", matched_pairs)
print("Number of matched pairs:", matched_pairs_count)
# Out:
# Words at level 3 :
# Embroidery and Needlework
# Lace Crocheting Knitting and Knotting
# Woven Textiles
# Printed and Dyed Textiles
# Flags
# Headwear
# Neckwear
# Undergarments and Nightwear
# Women's Apparel
# Men's Apparel
# Infants' and Children's Apparel
# Footwear
# Costume Accessories (A-Z)
# Medical and Personal Hygiene Instruments
# Restraining Irons and Clothing
# Sets of Jewelry
# Jewelry (A-Z)
#
# Fracturs and Paintings
# Wood Carvings and Weathervanes
# Furniture and Decorative Accessories
# Ceramics and Chalkware
# Textiles
# Domestic Utensils Tools and Hardware
# Painting
# Furniture
# Ceramics
# Textiles and Costume
# Domestic Utensils and Tools
#
#
# Furniture
# Costume
# Domestic Utensils and Tools
# Art and Architecture
# Furniture and Furnishing Accessories
# Textiles and Costume
# Domestic Utensils and Tools (A-Z)
# Costume
#
# Art and Architecture
# Furniture and Mirrors
# Textiles and Costume
# Domestic Utensils and Tools
# Saddlery and Weapons
# Musical Instruments
#
#
#
# Interiors
# Exteriors
# Gardens
# Waterworks
# Ornamental Iron
# Paintings Documents and Prints
# Valentines and Paper Cuttings
#
#
# Nails and Pins
# Bolts Locks and Latches
# Drawer Pulls
# Hinges
# Door Knockers
# Tiebacks
# Marine Hardware
# Firearms
# Powder Horns and Flasks
# Ammunition Containers and Bullet Molds
# Cross Bows
# Swords Sabers and Daggers
# Knapsacks and Canteens
# Collars and Hobbles
# Saddles Bridles and Stirrups
# Horse Shoes
# Whips and Whip Sockets
# Bicycles
# Baby Carriages
# Coaches and Wagons
# Sleighs and Sleds
# Carts and Wheelbarrows
# Barometers Thermometers and Compasses
# Octants
# Plumblines and Levels
# Scales
#
#
# Fireplace Tools
# Andirons
# Firebacks
# Gridirons Waffle Irons and Toasters
# Trivets and Flatiron Holders
# Ovens and Broilers
# Warmers
# Stoves and Stove Equipment
# Match Boxes
# Candlesticks and Holders
# Chandeliers and Sconces
# Lamps
# Lanterns and Torches
# Lighting Accessories
# Spinning and Weaving Implements
# Sewing Tools
#
#
# Chairs and Tables
# Case Furniture
# Beds and Cradles
# Bathtubs
# Books and Albums
# Boxes and Cases
# Cellarets and Wine Coolers
# Clocks
# Decorations
# Desk Accessories
# Door Stops
# Fire Screens
# Globes
# Mirrors and Frames
# Racks and Stands
# Safes and Mail Boxes
# Tobacco Accessories
# Trays
# Trunks and Hat Boxes
# Vases
# Wall Pockets
#
# Marine Carvings
# Circus Carvings
# Carousel Carvings
# Advertising Figures and Signs
# Wooden Sculpture
#
# Weathervanes
# Whirligigs
#
# Earthenware
# Stoneware
# Ironstone
# Porcelain
# Tiles and Plaques
# Ceramic Figures
#
# Free Blown
# Mold Blown
# Pressed Glass
# Painted Glass and Decorated Glass
#
#
#
#
# Dolls
# Dolls Accessories
# Marionettes and Puppets
# Animals
# Vehicles
# Banks and Mechanical Toys
# Toys
#
# Percussion Instruments
# String Instruments
# Wind Instruments including Fifes Trumpets and Organs
# Firemen's Speaking Trumpets
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 5
#       3 json2_file = 'catalog_nested.json'
#       4 level_to_check = 3  # Specify the level you want to check
# ----> 5 matched_pairs = match_tokens(json1_file, json2_file, level_to_check)
#       6 matched_pairs_count = len(matched_pairs)
#       7 print("Matched pairs at level", level_to_check, ":", matched_pairs)
#
# Cell In[10], line 14, in match_tokens(json1, json2, level)
#      12 matched_pairs = []
#      13 for token in tokens1:
# ---> 14     for word in words2:
#      15         if token == word:
#      16             matched_pairs.append((token, word))
#
# TypeError: 'NoneType' object is not iterable
