# %% [markdown]
# # Match Title Tokens back to Catalog

# %%
import json

# %%
pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /Users/chakim2/anaconda3/lib/python3.11/site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-Levenshtein
# Out:
# Requirement already satisfied: python-Levenshtein in /Users/chakim2/anaconda3/lib/python3.11/site-packages (0.25.0)
# Requirement already satisfied: Levenshtein==0.25.0 in /Users/chakim2/anaconda3/lib/python3.11/site-packages (from python-Levenshtein) (0.25.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.1.0 in /Users/chakim2/anaconda3/lib/python3.11/site-packages (from Levenshtein==0.25.0->python-Levenshtein) (3.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from fuzzywuzzy import fuzz

# %%
def extract_tokens(data):
    tokens = []
    for item in data:
        if "filtered_tokens" in item:
            tokens.extend(item["filtered_tokens"])
    return tokens

# %%
def extract_words_at_level(data, level):
    if level == 1:
        return list(data.keys())
    else:
        return _extract_words_at_level(data, level, 1)

# %%
def _extract_words_at_level(data, level, current_level):
    words = []
    for key, value in data.items():
        if isinstance(value, dict):
            if current_level < level:
                words.extend(_extract_words_at_level(value, level, current_level + 1))
            elif current_level == level:
                words.append(key)
    return words

# %%
def fuzzy_match(token, words):
    best_match = None
    highest_score = -1
    for word in words:
        ratio = fuzz.ratio(token.lower(), word.lower())
        if ratio > highest_score:
            highest_score = ratio
            best_match = word
    return best_match, highest_score

# %%
def match_tokens(json1, json2, level):
    # Load JSON data
    with open(json1, 'r') as f1, open(json2, 'r') as f2:
        data1 = json.load(f1)
        data2 = json.load(f2)

    # Extract tokens/words from JSON data
    tokens1 = extract_tokens(data1)
    words2 = extract_words_at_level(data2, level)

    # Match tokens to words using fuzzy matching
    matched_pairs = []
    if words2 is not None:  # Check if words2 is None before iterating
        for token in tokens1:
            best_match, score = fuzzy_match(token, words2)
            if score >= 80:  # Adjust this threshold as needed
                matched_pairs.append((token, best_match))
    return matched_pairs

# %%
# Example usage
json1_file = 'cleaned_titles_lc_tokens_sw.json'  # Use the path to your JSON file for dataset1
json2_file = 'catalog_nested.json'  # Use the path to your JSON file for dataset2
level_to_check = 5  # Specify the level you want to check
matched_pairs = match_tokens(json1_file, json2_file, level_to_check)
matched_pairs_count = len(matched_pairs)
print("Matched pairs at level", level_to_check, ":", matched_pairs)
print("Number of matched pairs:", matched_pairs_count)
# Out:
# Matched pairs at level 5 : [('bit', 'Bits'), ('bit', 'Bits'), ('clock', 'Clocks'), ('table', 'Tables'), ('ring', 'Rings'), ('bottle', 'Bottles'), ('bowl', 'Bowls'), ('bottle', 'Bottles'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('porringer', 'Porringers'), ('porringer', 'Porringers'), ('pitcher', 'Pitcher'), ('iron', 'Irons'), ('wood', 'Wood'), ('kettle', 'Kettles'), ('uniform', 'Uniforms'), ('earthenware', 'Earthenware'), ('churn', 'Churns'), ('churn', 'Churns'), ('bowl', 'Bowls'), ('bowl', 'Bowls'), ('prints', 'Pins'), ('mold', 'Molds'), ('chair', 'Chairs'), ('wooden', 'Wood'), ('chair', 'Chairs'), ('chair', 'Chairs'), ('wooden', 'Wood'), ('chair', 'Chairs'), ('iron', 'Irons'), ('table', 'Tables'), ('bell', 'Bells'), ('bottle', 'Bottles'), ('iron', 'Irons'), ('chair', 'Chairs'), ('sampler', 'Samplers'), ('eagle', 'Eagles'), ('bowl', 'Bowls'), ('fan', 'Fans'), ('iron', 'Irons'), ('garden', 'Gardens'), ('clock', 'Clocks'), ('wooden', 'Wood'), ('bed', 'Beds'), ('bottle', 'Bottles'), ('bottle', 'Bottles'), ('pitcher', 'Pitcher'), ('pitcher', 'Pitcher'), ('bell', 'Bells'), ('clock', 'Clocks'), ('jack', 'Jacks'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('brackets', 'Bracelets'), ('iron', 'Irons'), ('brackets', 'Bracelets'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('gates', 'Graters'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('hardware', 'Hardware'), ('iron', 'Irons'), ('iron', 'Irons'), ('garde', 'Gardens'), ('iron', 'Irons'), ('iron', 'Irons'), ('lock', 'Clocks'), ('lock', 'Clocks'), ('iron', 'Irons'), ('eagle', 'Eagles'), ('earrings', 'Earrings'), ('clock', 'Clocks'), ('stool', 'Tools'), ('grinder', 'Grinders'), ('table', 'Tables'), ('clock', 'Clocks'), ('bowl', 'Bowls'), ('compote', 'Compotes'), ('compote', 'Compotes'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('spurs', 'Spurs'), ('metal', 'Metal'), ('iron', 'Irons'), ('pail', 'Pail'), ('plane', 'Planes'), ('yoke', 'Yokes'), ('wrench', 'Wrenches'), ('bed', 'Beds'), ('yoke', 'Yokes'), ('decoy', 'Decoys'), ('clock', 'Clocks'), ('cradle', 'Cradles'), ('prints', 'Pins'), ('prints', 'Pins'), ('samples', 'Samplers'), ('sampler', 'Samplers'), ('prints', 'Pins'), ('bowl', 'Bowls'), ('boxes', 'Boxes'), ('designs', 'Signs'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('iron', 'Irons'), ('lamp', 'Clamps'), ('wood', 'Wood'), ('blocks', 'Clocks'), ('mold', 'Molds'), ('boxes', 'Boxes'), ('prints', 'Pins'), ('wood', 'Wood'), ('cemetery', 'Cemetery Art'), ('spur', 'Spurs'), ('camp', 'Clamps'), ('lamp', 'Clamps'), ('funnel', 'Funnels'), ('pin', 'Pins'), ('saw', 'Saws'), ('lamp', 'Clamps'), ('chair', 'Chairs'), ('table', 'Tables'), ('furniture', 'Furniture'), ('wooden', 'Wood'), ('sign', 'Signs'), ('sign', 'Signs'), ('iron', 'Irons'), ('iron', 'Irons'), ('stool', 'Tools'), ('comb', 'Combs'), ('clamp', 'Clamps'), ('holds', 'Molds'), ('hooks', 'Hooks'), ('lock', 'Clocks'), ('wood', 'Wood'), ('rearing', 'Earrings'), ('clock', 'Clocks'), ('firemark', 'Firemarks'), ('wood', 'Wood'), ('balls', 'Bells'), ('lock', 'Clocks'), ('belt', 'Belts'), ('sampler', 'Samplers'), ('stool', 'Tools'), ('chair', 'Chairs'), ('auger', 'Augers'), ('basket', 'Baskets'), ('bit', 'Bits'), ('iron', 'Irons'), ('iron', 'Irons'), ('masher', 'Mashers'), ('camp', 'Clamps'), ('basket', 'Baskets'), ('scoop', 'Scoops'), ('sign', 'Signs'), ('sign', 'Signs'), ('lamp', 'Clamps'), ('necklace', 'Necklaces'), (' ...
# Number of matched pairs: 6177

# %%
def match_tokens(json1, json2, level, output_file):
    # Load JSON data
    with open(json1, 'r') as f1:
        data1 = json.load(f1)
    with open(json2, 'r') as f2:
        data2 = json.load(f2)

    # Extract tokens/words from JSON data
    tokens1 = extract_tokens(data1)
    words2 = extract_words_at_level(data2, level)

    # Match tokens to words using fuzzy matching
    matched_pairs = []
    if words2 is not None:  # Check if words2 is None before iterating
        for token in tokens1:
            best_match, score = fuzzy_match(token, words2)
            if score >= 80:  # Adjust this threshold as needed
                matched_pairs.append((token, best_match))
                # Append objectid from dataset1 to dataset2
                matched_objectids = []
                for item in data1:
                    if token in item.get("filtered_tokens", []):
                        objectid = item.get("objectid")
                        if objectid:
                            matched_objectids.append(objectid)
                # Traverse dataset2 to find the matched array and append objectids
                current_level = data2
                for word in best_match.split('/'):
                    current_level = current_level.get(word, {})  # Handle missing levels
                    if not isinstance(current_level, dict):  # Handle non-dict types
                        break  # Stop traversal if a non-dict type is encountered
                if isinstance(current_level, dict):  # Append objectids only if a dict is found
                    current_level.setdefault('matched_objectids', []).extend(matched_objectids)

    # Write modified data to the output file
    with open(output_file, 'w') as f_out:
        json.dump(data2, f_out, indent=4)

    return matched_pairs

# %%
# Example usage
json1_file = 'cleaned_titles_lc_tokens_sw.json'  # Use the path to your JSON file for dataset1
json2_file = 'catalog_nested.json' # Use the path to your JSON file for dataset2
level_to_check = 5  # Specify the level you want to check

# Specify the path for the output file
output_file = 'matchTitleTokens.json'

# Call match_tokens with the output file parameter
matched_pairs = match_tokens(json1_file, json2_file, level_to_check, output_file)

matched_pairs_count = len(matched_pairs)
print("Matched pairs at level", level_to_check, ":", matched_pairs)
print("Number of matched pairs:", matched_pairs_count)
# Out:
# Matched pairs at level 5 : [('bit', 'Bits'), ('bit', 'Bits'), ('clock', 'Clocks'), ('table', 'Tables'), ('ring', 'Rings'), ('bottle', 'Bottles'), ('bowl', 'Bowls'), ('bottle', 'Bottles'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('lamp', 'Clamps'), ('porringer', 'Porringers'), ('porringer', 'Porringers'), ('pitcher', 'Pitcher'), ('iron', 'Irons'), ('wood', 'Wood'), ('kettle', 'Kettles'), ('uniform', 'Uniforms'), ('earthenware', 'Earthenware'), ('churn', 'Churns'), ('churn', 'Churns'), ('bowl', 'Bowls'), ('bowl', 'Bowls'), ('prints', 'Pins'), ('mold', 'Molds'), ('chair', 'Chairs'), ('wooden', 'Wood'), ('chair', 'Chairs'), ('chair', 'Chairs'), ('wooden', 'Wood'), ('chair', 'Chairs'), ('iron', 'Irons'), ('table', 'Tables'), ('bell', 'Bells'), ('bottle', 'Bottles'), ('iron', 'Irons'), ('chair', 'Chairs'), ('sampler', 'Samplers'), ('eagle', 'Eagles'), ('bowl', 'Bowls'), ('fan', 'Fans'), ('iron', 'Irons'), ('garden', 'Gardens'), ('clock', 'Clocks'), ('wooden', 'Wood'), ('bed', 'Beds'), ('bottle', 'Bottles'), ('bottle', 'Bottles'), ('pitcher', 'Pitcher'), ('pitcher', 'Pitcher'), ('bell', 'Bells'), ('clock', 'Clocks'), ('jack', 'Jacks'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('brackets', 'Bracelets'), ('iron', 'Irons'), ('brackets', 'Bracelets'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('gates', 'Graters'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('hardware', 'Hardware'), ('iron', 'Irons'), ('iron', 'Irons'), ('garde', 'Gardens'), ('iron', 'Irons'), ('iron', 'Irons'), ('lock', 'Clocks'), ('lock', 'Clocks'), ('iron', 'Irons'), ('eagle', 'Eagles'), ('earrings', 'Earrings'), ('clock', 'Clocks'), ('stool', 'Tools'), ('grinder', 'Grinders'), ('table', 'Tables'), ('clock', 'Clocks'), ('bowl', 'Bowls'), ('compote', 'Compotes'), ('compote', 'Compotes'), ('iron', 'Irons'), ('iron', 'Irons'), ('iron', 'Irons'), ('spurs', 'Spurs'), ('metal', 'Metal'), ('iron', 'Irons'), ('pail', 'Pail'), ('plane', 'Planes'), ('yoke', 'Yokes'), ('wrench', 'Wrenches'), ('bed', 'Beds'), ('yoke', 'Yokes'), ('decoy', 'Decoys'), ('clock', 'Clocks'), ('cradle', 'Cradles'), ('prints', 'Pins'), ('prints', 'Pins'), ('samples', 'Samplers'), ('sampler', 'Samplers'), ('prints', 'Pins'), ('bowl', 'Bowls'), ('boxes', 'Boxes'), ('designs', 'Signs'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('mold', 'Molds'), ('iron', 'Irons'), ('lamp', 'Clamps'), ('wood', 'Wood'), ('blocks', 'Clocks'), ('mold', 'Molds'), ('boxes', 'Boxes'), ('prints', 'Pins'), ('wood', 'Wood'), ('cemetery', 'Cemetery Art'), ('spur', 'Spurs'), ('camp', 'Clamps'), ('lamp', 'Clamps'), ('funnel', 'Funnels'), ('pin', 'Pins'), ('saw', 'Saws'), ('lamp', 'Clamps'), ('chair', 'Chairs'), ('table', 'Tables'), ('furniture', 'Furniture'), ('wooden', 'Wood'), ('sign', 'Signs'), ('sign', 'Signs'), ('iron', 'Irons'), ('iron', 'Irons'), ('stool', 'Tools'), ('comb', 'Combs'), ('clamp', 'Clamps'), ('holds', 'Molds'), ('hooks', 'Hooks'), ('lock', 'Clocks'), ('wood', 'Wood'), ('rearing', 'Earrings'), ('clock', 'Clocks'), ('firemark', 'Firemarks'), ('wood', 'Wood'), ('balls', 'Bells'), ('lock', 'Clocks'), ('belt', 'Belts'), ('sampler', 'Samplers'), ('stool', 'Tools'), ('chair', 'Chairs'), ('auger', 'Augers'), ('basket', 'Baskets'), ('bit', 'Bits'), ('iron', 'Irons'), ('iron', 'Irons'), ('masher', 'Mashers'), ('camp', 'Clamps'), ('basket', 'Baskets'), ('scoop', 'Scoops'), ('sign', 'Signs'), ('sign', 'Signs'), ('lamp', 'Clamps'), ('necklace', 'Necklaces'), (' ...
# Number of matched pairs: 6177

# %%
def match_tokens(json1, json2, level, output_file):
    # Load JSON data
    with open(json1, 'r') as f1:
        data1 = json.load(f1)
    with open(json2, 'r') as f2:
        data2 = json.load(f2)

    # Extract tokens/words from JSON data
    tokens1 = extract_tokens(data1)
    words2 = extract_words_at_level(data2, level)

    # Match tokens to words using fuzzy matching
    matched_pairs = []
    if words2 is not None:  # Check if words2 is None before iterating
        for token in tokens1:
            best_match, score = fuzzy_match(token, words2)
            if score >= 80:  # Adjust this threshold as needed
                matched_pairs.append((token, best_match))
                # Append objectid from dataset1 to dataset2
                matched_objectids = []
                for item in data1:
                    if token in item.get("filtered_tokens", []):
                        objectid = item.get("objectid")
                        if objectid:
                            matched_objectids.append(objectid)
                # Traverse dataset2 to find the appropriate array and append objectids
                current_level = data2
                for word in best_match.split('/'):
                    current_level = current_level.get(word, {})  # Handle missing levels
                current_level.setdefault('matched_objectids', []).extend(matched_objectids)

    # Write modified data to the output file
    with open(output_file, 'w') as f_out:
        json.dump(data2, f_out, indent=4)

    return matched_pairs

# Example usage
json1_file = 'cleaned_titles_lc_tokens_sw.json'  # Use the path to your JSON file for dataset1
json2_file = 'catalog_nested.json'
level_to_check = 5  # Specify the level you want to check
output_file = 'matchTitleTokens2.json'
matched_pairs = match_tokens(json1_file, json2_file, level_to_check, output_file)
